# %%
from read_eco_data import preprocess as pp

df = pp('./data.json')
df
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# c:\Users\esnd1\OneDrive\Documents\btp\final_read_data.ipynb Cell 1 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/esnd1/OneDrive/Documents/btp/final_read_data.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from read_eco_data import preprocess as pp
# ----> <a href='vscode-notebook-cell:/c%3A/Users/esnd1/OneDrive/Documents/btp/final_read_data.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> df = pp('./data.json')
#       <a href='vscode-notebook-cell:/c%3A/Users/esnd1/OneDrive/Documents/btp/final_read_data.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> df
#
# File c:\Users\esnd1\OneDrive\Documents\btp\read_eco_data.py:38, in preprocess(filepath)
#      35     if(t > pd.to_datetime('01-01-2023')):
#      36         break
# ---> 38     s += (t_esg_com[1] - t_esg_ind[1])/t_esg_ind[1];
#      40 s /= len(esg[i]);
#      42 diff_array.append(s);
#
# ...
