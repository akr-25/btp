# %%
from read_eco_data import preprocess as pp

df = pp('./data.json')
# Out:
#         ticker  eco_score
# 0      3MINDIA   0.163942
# 1       5PAISA   0.580448
# 2          AWL   0.219065
# 3         ATGL   0.255459
# 4      ADANIGR   0.050062
# 5   ADANIPORTS   0.088798
# 6   ADANIPOWER   0.037411
# 7       ADANIT   0.220926
# 8        ADYAF   0.119228
# 9    AEGISCHEM   0.249265
# 10        AHLU   1.041885
# 11        ALBK   0.069648
# 12    ALLCARGO   0.174117
# 13  AMARAJABAT   0.057363
# 14    ANANTRAJ   0.131837
# 15  ANDHRABANK   0.047827
# 16        APCO   0.140000
# 17  APOLLOTYRE   0.004016
# 18  ASAHIINDIA   0.031697
# 19    ASHOKLEY   0.127580
# 20      ASHOKA   0.193928
# 21  ASIANPAINT   0.012326
# 22      AUBANK   0.091694
# 23   AUTOAXLES   0.006003
# 24       DMART   0.144802
# 25    AXISBANK   0.077118
# 26        AZRE   0.109815
# 27  BAJAJ-AUTO   0.239835
# 28    BAJAJCON   0.078759
# 29   BAJAJELEC   0.130081
# 30  BAJFINANCE   0.208245
# 31  BAJAJFINSV   0.264433
# 32  BAJAJHLDNG   0.065935
# 33  BALKRISIND   0.082626
# ...

# %%
ticker_list = df['ticker'].tolist()

# %%
import pandas as pd

# %%
for ticker in ticker_list: 
    try: 
        print(ticker)
        df = pd.read_json('./data/' + ticker + '.json')
    except Exception as e:
        print(e)
# Out:
# 3MINDIA
# 5PAISA
# AWL
# ATGL
# ADANIGR
# File ./data/ADANIGR.json does not exist
# ADANIPORTS
# ADANIPOWER
# ADANIT
# File ./data/ADANIT.json does not exist
# ADYAF
# File ./data/ADYAF.json does not exist
# AEGISCHEM
# AHLU
# File ./data/AHLU.json does not exist
# ALBK
# File ./data/ALBK.json does not exist
# ALLCARGO
# AMARAJABAT
# ANANTRAJ
# ANDHRABANK
# File ./data/ANDHRABANK.json does not exist
# APCO
# File ./data/APCO.json does not exist
# APOLLOTYRE
# ASAHIINDIA
# ASHOKLEY
# ASHOKA
# ASIANPAINT
# AUBANK
# AUTOAXLES
# DMART
# AXISBANK
# AZRE
# File ./data/AZRE.json does not exist
# BAJAJ-AUTO
# BAJAJCON
# BAJAJELEC
# BAJFINANCE
# BAJAJFINSV
# BAJAJHLDNG
# BALKRISIND
# BALMLAWRIE
# BALRAMCHIN
# BANDHANBNK
# BANKBARODA
# BANKA
# BDL
# BEL
# BHARATFORG
# BPCL
# BHARTIARTL
# INDUSTOWER
# ABCAPITAL
# BLS
# BLUEDART
# BORORENEW
# BRIGADE
# BRITANNIA
# BUTTERFLY
# CANFINHOME
# CANBK
# CGCL
# CARE
# File ./data/CARE.json does not exist
# CARTRADE
# CCL
# CEATLTD
