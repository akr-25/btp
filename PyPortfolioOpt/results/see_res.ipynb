# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('merged.csv')

# %%
df.head()
# Out:
#   start  end  sharpe_ratio  returns  risk method      stockname  BAJFINANCE  \
# 0   NaN  NaN           NaN      NaN   NaN    NaN  sharpe_stocks  594.083862
# 1   NaN  NaN           NaN      NaN   NaN    NaN  sharpe_stocks  589.854309
# 2   NaN  NaN           NaN      NaN   NaN    NaN  sharpe_stocks  584.533142
# 3   NaN  NaN           NaN      NaN   NaN    NaN  sharpe_stocks  595.194885
# 4   NaN  NaN           NaN      NaN   NaN    NaN  sharpe_stocks  595.102356
#
#    BAJAJFINSV        PGHL  ...  JKIL  HCC  NCC  GNFC  COSMOFIRST  HINDOILEXP  \
# 0  197.527466  609.568726  ...   NaN  NaN  NaN   NaN         NaN         NaN
# 1  195.107910  604.125488  ...   NaN  NaN  NaN   NaN         NaN         NaN
# 2  193.763702  601.423340  ...   NaN  NaN  NaN   NaN         NaN         NaN
# 3  193.021896  598.682251  ...   NaN  NaN  NaN   NaN         NaN         NaN
# 4  191.876862  585.837708  ...   NaN  NaN  NaN   NaN         NaN         NaN
#
#    CHAMBLFERT  CESC  NLCINDIA  TNPL
# ...
