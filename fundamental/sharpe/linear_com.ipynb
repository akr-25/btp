# %%
import pandas as pd
import numpy as np

# %%
def get_data(stocks, start_timestamp=None, end_timestamp=None):
    data = {}
    errors = []
    for stock in stocks:
        stock = stock.replace('.NS', '')
        stock = stock.replace('.BO', '')
        try:
            df = pd.read_csv('../../data/{}.csv'.format(stock))
            df['Date'] = pd.to_datetime(df['Date'])
            if start_timestamp and end_timestamp:
                df = df[(df['Date'] >= start_timestamp) & (df['Date'] <= end_timestamp)]
            df = df.set_index('Date')
            
            data[stock] = df
        except Exception as e:
            print('Error in reading data for {}'.format(stock))
            print(e)
            errors.append(stock)
    return data, errors

# %%
start_timestamp = '01/01/2016'
end_timestamp = '01/01/2020'

stocklist = pd.read_csv('../../esg_nse_yahoo_final.csv')
data, errors = get_data(stocklist['ticker'], start_timestamp, end_timestamp)

# %%
stocks = list(data.keys())
stocks
# Out:
# ['3MINDIA',
#  'AARTIDRUGS',
#  'AARTIIND',
#  'ABB',
#  'ACC',
#  'ACE',
#  'ADANIPORTS',
#  'AEGISCHEM',
#  'BBOX',
#  'ATFL',
#  'AIAENG',
#  'AJANTPHARM',
#  'ALKYLAMINE',
#  'ALLCARGO',
#  'ALOKINDS',
#  'AMARAJABAT',
#  'AMBUJACEM',
#  'ANANTRAJ',
#  'APARINDS',
#  'APOLLOHOSP',
#  'APOLLOTYRE',
#  'ARVIND',
#  'ASAHIINDIA',
#  'ASHOKLEY',
#  'ASIANPAINT',
#  'ASTRAMICRO',
#  'ASTRAZEN',
#  'ATUL',
#  'AUROPHARMA',
#  'AUTOAXLES',
#  'AXISBANK',
#  'BAJAJ-AUTO',
#  'BAJAJELEC',
#  'BAJFINANCE',
#  'BAJAJFINSV',
#  'BAJAJHIND',
#  'BAJAJHLDNG',
#  'BALAMINES',
#  'BALKRISIND',
#  'BALMLAWRIE',
#  'BALRAMCHIN',
#  'BANKBARODA',
#  'BANKINDIA',
#  'MAHABANK',
#  'BANARISUG',
#  'BASF',
#  'BATAINDIA',
#  'BEML',
#  'BERGEPAINT',
#  'BEL',
#  'BHARATFORG',
#  'BHEL',
#  'BPCL',
#  'BHARATRAS',
#  'BHARTIARTL',
#  'BIOCON',
#  'BIRLACORPN',
#  'BSOFT',
#  'BLUEDART',
#  'BLUESTARCO',
#  'BBTC',
#  'BOMDYEING',
#  'BRIGADE',
#  'BRITANNIA',
#  'ZYDUSLIFE',
#  'CANFINHOME',
#  'CANBK',
#  'CARBORUNIV',
#  'CASTROLIND',
#  'CCL',
#  'CEATLTD',
#  'CENTRALBK',
#  'CENTURYPLY',
#  'CENTURYTEX',
#  'CERA',
#  'CESC',
#  'CGPOWER',
#  'CHAMBLFERT',
#  'CHENNPETRO',
#  'CHOLAFIN',
#  'CIPLA',
#  'CUB',
#  'COFORGE',
#  'COLPAL',
#  'CONCOR',
#  'COROMANDEL',
#  'COSMOFIRST',
#  'CRISIL',
#  'CUMMINSIND',
#  'DABUR',
#  'DALMIASUG',
#  'DCMSHRIRAM',
#  'DEEPAKFERT',
#  'DCBBANK',
#  'DISHTV',
#  'DCAL',
#  'DIVISLAB',
#  'DLF',
#  'DRREDDY',
#  'EIDPARRY',
#  'ECLERX',
#  'EDELWEISS',
#  'EICHERMOT',
#  'EIHOTEL',
#  'ELECON',
#  'ELGIEQUIP',
#  'EMAMILTD',
#  'EMCO',
#  'ENGINERSIN',
#  'ESABINDIA',
#  'ESCORTS',
#  'EPL',
#  'EVEREADY',
#  'EXIDEIND',
#  'SCHAEFFLER',
#  'FDC',
#  'FACT',
#  'GNFC',
#  'FINCABLES',
#  'FINPIPE',
#  'FSL',
#  'FORTIS',
#  'GAIL',
#  'GANESHHOUC',
#  'GARFIBRES',
#  'GEPIL',
#  'GET&D',
#  'GHCL',
#  'GICHSGFIN',
#  'GLAXO',
#  'GLENMARK',
#  'GMRINFRA',
#  'GPIL',
#  'GODFRYPHLP',
#  'GODREJCP',
#  'GODREJIND',
#  'GOKEX',
#  'GRANULES',
#  'GRAPHITE',
#  'GRASIM',
#  'GESHIP',
#  'GREAVESCOT',
#  'GREENPLY',
#  'GRINDWELL',
#  'GTLINFRA',
#  'GUJALKALI',
#  'GAEL',
#  'GMDCLTD',
#  'GSFC',
#  'GSPL',
#  'GOCLCORP',
#  'GVKPIL',
#  'HMT',
#  'HAVELLS',
#  'HBLPOWER',
#  'HCLTECH',
#  'HDFCBANK',
#  'HEG',
#  'HEIDELBERG',
#  'HERITGFOOD',
#  'HEROMOTOCO',
#  'HIKAL',
#  'HIL',
#  'HFCL',
#  'HSCL',
#  'HIMATSEIDE',
#  'HINDALCO',
#  'HGS',
#  'HCC',
#  'HINDOILEXP',
#  'HINDPETRO',
#  'HINDUNILVR',
#  'HINDZINC',
#  'JCHAC',
#  'HONAUT',
#  'HDIL',
#  'AGI',
#  'AKZOINDIA',
#  'ICICIBANK',
#  'IDBI',
#  'IDEA',
#  'IFBIND',
#  'IFCI',
#  'IGARASHI',
#  'INDIAGLYCO',
#  'IIFL',
#  'IBREALEST',
#  'DHANI',
#  'INDIANB',
#  'INDIANHUME',
#  'IOC',
#  'IOB',
#  'ICIL',
#  'INDOCO',
#  'IGL',
#  'INDUSINDBK',
#  'NAUKRI',
#  'INFY',
#  'CYIENT',
#  'IDFC',
#  'INGERRAND',
#  'IPCALAB',
#  'IRB',
#  'ITC',
#  'ITI',
#  'JKIL',
#  'JKCEMENT',
#  'JBCHEPHARM',
#  'JAGRAN',
#  'JAICORPLTD',
#  'JISLJALEQS',
#  'JPASSOCIAT',
#  'JPPOWER',
#  'J&KBANK',
#  'JAYNECOIND',
#  'JBMA',
#  'JINDALPOLY',
#  'JINDALSAW',
#  'JSL',
#  'JINDALSTEL',
#  'JKLAKSHMI',
#  'JKPAPER',
#  'JKTYRE',
#  'JMFINANCIL',
#  'JSWHL',
#  'JSWSTEEL',
#  'JUBLPHARMA',
#  'JYOTHYLAB',
#  'KSB',
#  'KAJARIACER',
#  'KANSAINER',
#  'KSCL',
#  'KCP',
#  'KEC',
#  'KEI',
#  'KKCL',
#  'KIRLOSBROS',
#  'KIRLOSENG',
#  'KOTAKBANK',
#  'KPRMILL',
#  'KRBL',
#  'LAOPALA',
#  'LAXMIMACH',
#  'LT',
#  'LICHSGFIN',
#  'LINDEINDIA',
#  'DAAWAT',
#  'LUPIN',
#  'MAHSCOOTER',
#  'MAHSEAMLES',
#  'M&MFIN',
#  'M&M',
#  'MAHLIFE',
#  'MRPL',
#  'MARICO',
#  'MARKSANS',
#  'MARUTI',
#  'MFSL',
#  'MCLEODRUSS',
#  'MERCATOR',
#  'UNOMINDA',
#  'MIRZAINT',
#  'MOTILALOFS',
#  'MPHASIS',
#  'MRF',
#  'NATCOPHARM',
#  'NATIONALUM',
#  'NFL',
#  'NAVA',
#  'NAVINFLUOR',
#  'NAVNETEDUL',
#  'NCC',
#  'NESCO',
#  'NETWORK18',
#  'NEULANDLAB',
#  'NLCINDIA',
#  'NIITLTD',
#  'NMDC',
#  'NOCIL',
#  'NTPC',
#  'ONGC',
#  'OLECTRA',
#  'OMAXE',
#  'OFSS',
#  'PAGEIND',
#  'PATANJALI',
#  'PETRONET',
#  'PFIZER',
#  'PCBL',
#  'PHOENIXLTD',
#  'PIDILITIND',
#  'PEL',
#  'POLYPLEX',
#  'POONAWALLA',
#  'PFC',
#  'POWERGRID',
#  'PRAJIND',
#  'PFOCUS',
#  'PRSMJOHNSN',
#  'PGHL',
#  'PGHH',
#  'PTC',
#  'PUNJLLOYD',
#  'PNB',
#  'RADICO',
#  'RAIN',
#  'RAJESHEXPO',
#  'RALLIS',
#  'RAMCOCEM',
#  'RKFORGE',
#  'RCF',
#  'RATNAMANI',
#  'RAYMOND',
#  'REDINGTON',
#  'RELCAPITAL',
#  'RCOM',
#  'RELIANCE',
#  'RELINFRA',
#  'RPOWER',
#  'RELIGARE',
#  'RECLTD',
#  'SADBHAV',
#  'SANGHVIMOV',
#  'SANOFI',
#  'SCI',
#  'SHREECEM',
#  'RENUKA',
#  'SHRIRAMFIN',
#  'SIEMENS',
#  'SIYSIL',
#  'SKFINDIA',
#  'SMLISUZU',
#  'SOBHA',
#  'SOLARINDS',
#  'SOMANYCERA',
#  'SONATSOFTW',
#  'SOUTHBANK',
#  'SREINFRA',
#  'SRF',
#  'SBIN',
#  'SAIL',
#  'SSWL',
#  'STLTECH',
#  'STAR',
#  'STYRENIX',
#  'SUDARSCHEM',
#  'SPARC',
#  'SUNPHARMA',
#  'SUNTV',
#  'SUNCLAYLTD',
#  'SUNDRMFAST',
#  'SUPRAJIT',
#  'SURYAROSNI',
#  'SUVEN',
#  'SUZLON',
#  'TAKE',
#  'TNPL',
#  'TANLA',
#  'TATACHEM',
#  'TATACOFFEE',
#  'TATACOMM',
#  'TCS',
#  'TATAELXSI',
#  'TATACONSUM',
#  'TATAINVEST',
#  'TATAMETALI',
#  'TATAMOTORS',
#  'TATAPOWER',
#  'TATASTLLP',
#  'TATASTEEL',
#  'TTML',
#  'TECHM',
#  'TECHNOE',
#  'TEXRAIL',
#  'FEDERALBNK',
#  'INDIACEM',
#  'KTKBANK',
#  'KARURVYSYA',
#  'SUPREMEIND',
#  'TINPLATE',
#  'WSTCSTPAPR',
#  'THERMAX']

# %%
data[stocks[0]].head()
# Out:
#                                    Open          High           Low  \
# Date
# 2016-01-01 00:00:00+05:30  10920.853273  10976.478102  10732.130488
# 2016-01-04 00:00:00+05:30  10856.698629  10856.698629  10136.591919
# 2016-01-05 00:00:00+05:30  10591.653191  10593.185978  10276.971471
# 2016-01-06 00:00:00+05:30  10301.886270  10489.698540  10080.727928
# 2016-01-07 00:00:00+05:30  10206.015919  10358.421555  10066.162667
#
#                                   Close  Volume  Dividends  Stock Splits
# Date
# 2016-01-01 00:00:00+05:30  10848.986328     400        0.0           0.0
# 2016-01-04 00:00:00+05:30  10478.965820    1002        0.0           0.0
# 2016-01-05 00:00:00+05:30  10333.841797     541        0.0           0.0
# 2016-01-06 00:00:00+05:30  10199.930664     872        0.0           0.0
# 2016-01-07 00:00:00+05:30  10227.863281     381        0.0           0.0

# %%
def sharpes_ratio(returns, risk_free_rate=0.06):
    return (returns.mean()*252 - risk_free_rate) / returns.std()

def get_returns(data, stock):
    df = data[stock]
    df['returns'] = df['Close'].pct_change()
    df['returns'] = df['returns'].dropna()
    return df['returns']


def get_sharpes_ratio(data, stock):
    returns = get_returns(data, stock)
    return sharpes_ratio(returns)

sharpes_ratios = {}
for stock in stocks:
    sharpes_ratios[stock] = get_sharpes_ratio(data, stock)

# sort the stocks by sharpes ratio
sorted_stocks = sorted(sharpes_ratios.items(), key=lambda kv: kv[1], reverse=True)
sorted_stocks
# Out:
# [('BAJFINANCE', 22.783808982485407),
#  ('BAJAJFINSV', 20.06759305452037),
#  ('PGHL', 20.00511938701802),
#  ('IGL', 19.23049358966377),
#  ('UNOMINDA', 18.832771081798274),
#  ('OLECTRA', 18.12756418432204),
#  ('TATAMETALI', 17.708138284924377),
#  ('BATAINDIA', 17.610719752701335),
#  ('HDFCBANK', 17.336202030060306),
#  ('DHANI', 17.048600618937346),
#  ('BHARATRAS', 16.36315844087536),
#  ('RELIANCE', 16.32971397065721),
#  ('HONAUT', 16.180517096106204),
#  ('HEG', 15.748484326616008),
#  ('CUB', 15.594512868616135),
#  ('AARTIIND', 15.418393235644922),
#  ('PCBL', 14.925372264248542),
#  ('HINDUNILVR', 14.803539061596208),
#  ('BIOCON', 14.51329590203062),
#  ('KEI', 14.30094312034446),
#  ('GRAPHITE', 14.26780340750306),
#  ('PIDILITIND', 14.140859292320306),
#  ('SUNDRMFAST', 13.987824654539663),
#  ('MAHSCOOTER', 13.725059998106452),
#  ('ESCORTS', 13.66856226283056),
#  ('BALKRISIND', 13.498626352977453),
#  ('BERGEPAINT', 13.467073685205973),
#  ('COROMANDEL', 13.39293926347503),
#  ('SUDARSCHEM', 13.35259461762433),
#  ('HSCL', 13.30208228513219),
#  ('PGHH', 13.11541862028753),
#  ('KOTAKBANK', 12.981336597172016),
#  ('GARFIBRES', 12.799133856891658),
#  ('ALKYLAMINE', 12.790490703745393),
#  ('JSWSTEEL', 12.768576520459652),
#  ('NAUKRI', 12.548950362954425),
#  ('COFORGE', 12.453347135371697),
#  ('ATUL', 12.44867708068916),
#  ('SRF', 12.362435026144164),
#  ('WSTCSTPAPR', 12.058355068365367),
#  ('DCMSHRIRAM', 11.623302091521555),
#  ('NAVINFLUOR', 11.340318352847119),
#  ('GPIL', 11.334188941112451),
#  ('POLYPLEX', 11.206000858046856),
#  ('BLUESTARCO', 11.152397928422369),
#  ('PHOENIXLTD', 10.977324906480028),
#  ('ASIANPAINT', 10.869739253503262),
#  ('HINDALCO', 10.838530871271281),
#  ('JKPAPER', 10.77444743185923),
#  ('BALRAMCHIN', 10.752480471059231),
#  ('CHOLAFIN', 10.740127416680156),
#  ('RADICO', 10.70025163729463),
#  ('PETRONET', 10.679371127309786),
#  ('CHAMBLFERT', 10.672951665580156),
#  ('BRITANNIA', 10.60289784404419),
#  ('ICICIBANK', 10.576348014719487),
#  ('MAHSEAMLES', 10.423834370978952),
#  ('TATACONSUM', 10.372571334903322),
#  ('ITI', 10.249151868870879),
#  ('BAJAJHLDNG', 10.243395647606704),
#  ('MOTILALOFS', 10.161965197761072),
#  ('RAIN', 10.108331472377328),
#  ('HINDOILEXP', 10.07507240582673),
#  ('BALAMINES', 9.969545118618917),
#  ('HEIDELBERG', 9.85498282987324),
#  ('GAEL', 9.829217318434702),
#  ('JSWHL', 9.581238199519861),
#  ('GUJALKALI', 9.557270089556752),
#  ('HINDZINC', 9.537272343138481),
#  ('TCS', 9.503761958788582),
#  ('JKCEMENT', 9.492136936735665),
#  ('SONATSOFTW', 9.482308261600418),
#  ('HAVELLS', 9.465023611112127),
#  ('SKFINDIA', 9.367590213649137),
#  ('KANSAINER', 9.177531259205253),
#  ('RATNAMANI', 9.164498323916655),
#  ('DCBBANK', 9.153777519811346),
#  ('EPL', 9.150267238223496),
#  ('MPHASIS', 9.10395225349506),
#  ('HIL', 9.082734235016265),
#  ('BRIGADE', 9.015797341968055),
#  ('NESCO', 8.976343788570514),
#  ('INDIAGLYCO', 8.764065121527128),
#  ('ESABINDIA', 8.709158671237372),
#  ('RAMCOCEM', 8.700166601834619),
#  ('ASTRAZEN', 8.675782968429775),
#  ('ELGIEQUIP', 8.655865610337681),
#  ('TATASTEEL', 8.534410522510166),
#  ('LINDEINDIA', 8.51657447121326),
#  ('JMFINANCIL', 8.481857189739111),
#  ('BPCL', 8.414018465729225),
#  ('FINPIPE', 8.38393618239096),
#  ('TINPLATE', 8.359521869955383),
#  ('GNFC', 8.289279282928682),
#  ('SANOFI', 8.228123717199937),
#  ('BBTC', 8.078097477175405),
#  ('KEC', 8.041684075432102),
#  ('NOCIL', 7.853834710917997),
#  ('3MINDIA', 7.848376992867703),
#  ('PFIZER', 7.789238422712809),
#  ('EDELWEISS', 7.6722335847742595),
#  ('AIAENG', 7.665952637651694),
#  ('DALMIASUG', 7.64839919832399),
#  ('TATACHEM', 7.607043333730344),
#  ('DABUR', 7.605038536501675),
#  ('DLF', 7.5945749726412295),
#  ('GOCLCORP', 7.569492288436946),
#  ('SHREECEM', 7.506288246568832),
#  ('GREENPLY', 7.4859694984788705),
#  ('NMDC', 7.326185648758898),
#  ('AEGISCHEM', 7.267903548514399),
#  ('CANFINHOME', 7.0329140796624685),
#  ('SSWL', 7.031865741252739),
#  ('CARBORUNIV', 6.960089762669897),
#  ('PAGEIND', 6.926001203051652),
#  ('SUPREMEIND', 6.922828247374658),
#  ('JINDALSTEL', 6.771320658106954),
#  ('CESC', 6.7570090053147105),
#  ('BAJAJELEC', 6.6635489831906485),
#  ('AXISBANK', 6.437176054546779),
#  ('GRINDWELL', 6.424787391574008),
#  ('MRF', 6.307751758956141),
#  ('HINDPETRO', 6.297803059021999),
#  ('MARUTI', 6.265756484798172),
#  ('RECLTD', 6.230154467259494),
#  ('COLPAL', 6.226257961814129),
#  ('JBCHEPHARM', 6.219428918494125),
#  ('POWERGRID', 6.162771706149988),
#  ('MARICO', 6.141354959891535),
#  ('BALMLAWRIE', 6.139350145224399),
#  ('TATAINVEST', 6.053641189755359),
#  ('LT', 6.026284889598978),
#  ('PEL', 5.960441477239344),
#  ('BBOX', 5.868188882067918),
#  ('DIVISLAB', 5.787272888588228),
#  ('FACT', 5.749072029444145),
#  ('ACE', 5.74661875680625),
#  ('GODREJCP', 5.72433877352939),
#  ('FEDERALBNK', 5.684456459009631),
#  ('GSPL', 5.67167068680247),
#  ('AKZOINDIA', 5.608543110343198),
#  ('RAYMOND', 5.554114266220341),
#  ('TECHM', 5.5481420459837905),
#  ('JBMA', 5.488686756849934),
#  ('TANLA', 5.424021523966238),
#  ('INDUSINDBK', 5.392225600079047),
#  ('JINDALSAW', 5.314571401109626),
#  ('FINCABLES', 5.135611591750416),
#  ('IPCALAB', 5.057846591744817),
#  ('SOLARINDS', 5.0162810277911225),
#  ('GHCL', 4.8751951015183),
#  ('INFY', 4.732983270008933),
#  ('JSL', 4.703409711861644),
#  ('SBIN', 4.70322445526353),
#  ('KPRMILL', 4.644748433435184),
#  ('BHARTIARTL', 4.61006723488053),
#  ('SUPRAJIT', 4.510585917914966),
#  ('NATIONALUM', 4.367819074032722),
#  ('KSCL', 4.310928867347632),
#  ('IFBIND', 4.259825824689315),
#  ('BOMDYEING', 4.220239429086404),
#  ('ADANIPORTS', 4.196178365851687),
#  ('HCLTECH', 4.167496708318325),
#  ('IOC', 4.091341593894825),
#  ('IIFL', 4.075579358091424),
#  ('M&MFIN', 4.011759865262808),
#  ('JAICORPLTD', 3.945855309109062),
#  ('STLTECH', 3.9328877516612994),
#  ('SHRIRAMFIN', 3.907702243317468),
#  ('PFC', 3.8915053237706925),
#  ('JCHAC', 3.8854071995573256),
#  ('EICHERMOT', 3.8655204295671917),
#  ('GOKEX', 3.818536447130622),
#  ('IBREALEST', 3.7912249315282334),
#  ('JUBLPHARMA', 3.7833580379804297),
#  ('BIRLACORPN', 3.6842957849187203),
#  ('KRBL', 3.6563861811898213),
#  ('CONCOR', 3.597036046420984),
#  ('GMRINFRA', 3.518487600413769),
#  ('SOBHA', 3.457006961700267),
#  ('CERA', 3.3573909289955757),
#  ('PRAJIND', 3.2904615004183393),
#  ('BAJAJ-AUTO', 3.1657872370857922),
#  ('REDINGTON', 3.095195365323103),
#  ('SURYAROSNI', 3.0426713357589716),
#  ('FSL', 2.938229425568802),
#  ('EXIDEIND', 2.921252064217842),
#  ('HERITGFOOD', 2.8737970513458233),
#  ('GRASIM', 2.7488792710383194),
#  ('AUTOAXLES', 2.5322689419674593),
#  ('SIEMENS', 2.510584170637294),
#  ('THERMAX', 2.5029749703070743),
#  ('ASAHIINDIA', 2.490853012597898),
#  ('SUVEN', 2.4882763917588337),
#  ('BANARISUG', 2.4788336305785825),
#  ('GAIL', 2.3881498720959526),
#  ('INDIANHUME', 1.9612874346913758),
#  ('ATFL', 1.9603031172674674),
#  ('HGS', 1.9400704076600352),
#  ('SUNTV', 1.8095613491042146),
#  ('TATASTLLP', 1.6604268672654574),
#  ('ABB', 1.3160609927019944),
#  ('INDIANB', 1.309781357888073),
#  ('EIDPARRY', 1.279860084013148),
#  ('HIKAL', 1.2235680893980152),
#  ('COSMOFIRST', 1.1918518863012473),
#  ('NATCOPHARM', 1.1893225838863712),
#  ('MFSL', 1.133450751437687),
#  ('BHARATFORG', 1.0640322174228394),
#  ('APOLLOTYRE', 1.039642178175112),
#  ('GODFRYPHLP', 1.0218296424291804),
#  ('INGERRAND', 1.0216352970725768),
#  ('NIITLTD', 0.9767068533608245),
#  ('EIHOTEL', 0.9473824072173624),
#  ('BASF', 0.9327245044762484),
#  ('ASHOKLEY', 0.8766578596876322),
#  ('CANBK', 0.795222619524159),
#  ('DAAWAT', 0.7661440691534528),
#  ('KSB', 0.7284143795308955),
#  ('GODREJIND', 0.6697328347672903),
#  ('RCF', 0.6277874271893066),
#  ('GSFC', 0.5709873926138904),
#  ('GREAVESCOT', 0.5180084580112087),
#  ('PFOCUS', 0.44328380497461417),
#  ('SIYSIL', 0.4432583643549272),
#  ('KAJARIACER', 0.4387832148417462),
#  ('CENTURYTEX', 0.4233673621373735),
#  ('NFL', 0.41490224214127774),
#  ('HFCL', 0.3324469049802063),
#  ('ITC', 0.30341269796225884),
#  ('CENTURYPLY', 0.22790171737811538),
#  ('NAVNETEDUL', 0.12168405067363032),
#  ('ACC', 0.11399871706842693),
#  ('SAIL', 0.06722903165421282),
#  ('NTPC', 0.05017178591463059),
#  ('GEPIL', -0.09633841791748043),
#  ('TATACOMM', -0.15477922172772413),
#  ('PTC', -0.1889012966653834),
#  ('ANANTRAJ', -0.25142358273466314),
#  ('STYRENIX', -0.27385926967041135),
#  ('SUNCLAYLTD', -0.28474307070590094),
#  ('JYOTHYLAB', -0.3618523894397611),
#  ('TECHNOE', -0.3762709506611872),
#  ('NAVA', -0.3855858137804929),
#  ('RALLIS', -0.4165278906687497),
#  ('KIRLOSBROS', -0.42628583401603476),
#  ('AARTIDRUGS', -0.4438813399340177),
#  ('TATACOFFEE', -0.5323097756481606),
#  ('CEATLTD', -0.6835809594302727),
#  ('OMAXE', -0.815657200230939),
#  ('APOLLOHOSP', -0.8878780898789448),
#  ('NCC', -0.9028576259910951),
#  ('SCHAEFFLER', -0.9167134787613773),
#  ('CRISIL', -0.9480085615064472),
#  ('IDFC', -0.9550904625286917),
#  ('GRANULES', -0.9758938501874482),
#  ('CYIENT', -1.0939516370464146),
#  ('INDIACEM', -1.1041706854860514),
#  ('HEROMOTOCO', -1.1327694580359904),
#  ('AMBUJACEM', -1.2711087362533697),
#  ('RENUKA', -1.3261308129913914),
#  ('PRSMJOHNSN', -1.3359888883446445),
#  ('GLAXO', -1.3510731024224247),
#  ('FDC', -1.3550442493072055),
#  ('ENGINERSIN', -1.3623471688490185),
#  ('BEML', -1.4261756413865918),
#  ('TATAPOWER', -1.4848956819782504),
#  ('CCL', -1.4979345542616274),
#  ('BEL', -1.627068889437067),
#  ('GESHIP', -1.6618624884616262),
#  ('ALOKINDS', -1.6701956898505836),
#  ('KCP', -1.757719063821106),
#  ('MAHLIFE', -1.803323323804511),
#  ('DRREDDY', -1.900284309665421),
#  ('RAJESHEXPO', -1.9037310347902594),
#  ('LICHSGFIN', -2.028082096937939),
#  ('GVKPIL', -2.136530749248517),
#  ('NLCINDIA', -2.2168627899014273),
#  ('BSOFT', -2.3290014926813387),
#  ('GMDCLTD', -2.5656925094973517),
#  ('SCI', -2.5678581970844565),
#  ('KTKBANK', -2.5830877930001246),
#  ('RKFORGE', -2.592781079332481),
#  ('TAKE', -2.593321419177114),
#  ('MRPL', -2.6053697246820597),
#  ('IGARASHI', -2.6634244765573367),
#  ('JKLAKSHMI', -2.673495552241205),
#  ('DEEPAKFERT', -2.6952538448284225),
#  ('ONGC', -2.7301358013955017),
#  ('LAXMIMACH', -2.7510938242160843),
#  ('BANKBARODA', -2.7728362257158983),
#  ('HCC', -2.8522274706050537),
#  ('GICHSGFIN', -2.903458945174084),
#  ('FORTIS', -2.9050089318424677),
#  ('ZYDUSLIFE', -2.9892805509454954),
#  ('BANKINDIA', -3.1159431748954725),
#  ('TNPL', -3.1680617953553605),
#  ('POONAWALLA', -3.1959026516318367),
#  ('AGI', -3.198009266838225),
#  ('CHENNPETRO', -3.2046783919938826),
#  ('PNB', -3.292397936931099),
#  ('TATAELXSI', -3.4308834991359443),
#  ('AMARAJABAT', -3.45182867411693),
#  ('JKTYRE', -3.4946488359701493),
#  ('INDOCO', -3.6312336697350567),
#  ('M&M', -3.6809968278857697),
#  ('APARINDS', -4.01750064363272),
#  ('KARURVYSYA', -4.266094251944503),
#  ('NEULANDLAB', -4.266568447877069),
#  ('HIMATSEIDE', -4.393482317079535),
#  ('AJANTPHARM', -4.538952831485908),
#  ('ELECON', -4.6692430744356015),
#  ('JKIL', -4.873700606276156),
#  ('ASTRAMICRO', -4.942596424916051),
#  ('GANESHHOUC', -5.074917644168674),
#  ('SOUTHBANK', -5.224427144420753),
#  ('DCAL', -5.2445337189158225),
#  ('OFSS', -5.639470706355054),
#  ('JPPOWER', -5.734259979607948),
#  ('JINDALPOLY', -5.741810762470995),
#  ('KIRLOSENG', -5.822899954742639),
#  ('BAJAJHIND', -5.868167968324086),
#  ('SOMANYCERA', -5.927598338550134),
#  ('JAYNECOIND', -5.952682062999613),
#  ('SPARC', -5.956743069511115),
#  ('JPASSOCIAT', -6.004617592667781),
#  ('MIRZAINT', -6.396362195103203),
#  ('IDBI', -6.474633064870818),
#  ('TATAMOTORS', -6.479895082555545),
#  ('EMAMILTD', -6.485442749629988),
#  ('NETWORK18', -6.616477456580478),
#  ('GTLINFRA', -6.695397926772457),
#  ('TTML', -6.747295248646765),
#  ('CIPLA', -6.9701147176222635),
#  ('HBLPOWER', -7.086970165031147),
#  ('CASTROLIND', -7.479797392333712),
#  ('AUROPHARMA', -7.511485392985842),
#  ('ALLCARGO', -8.44074143746519),
#  ('BHEL', -8.45473583603908),
#  ('SUNPHARMA', -8.478434582720574),
#  ('SMLISUZU', -8.535509686682216),
#  ('CUMMINSIND', -8.773136432623634),
#  ('MAHABANK', -8.777883779200497),
#  ('ICIL', -8.889211321322165),
#  ('IRB', -9.821225257031205),
#  ('LAOPALA', -10.307574359174096),
#  ('ECLERX', -10.391161593521684),
#  ('MARKSANS', -10.653129050186841),
#  ('SADBHAV', -10.932500772670124),
#  ('DISHTV', -11.00532165544417),
#  ('IFCI', -11.059076571001068),
#  ('STAR', -11.17629242482792),
#  ('ARVIND', -11.269532749852907),
#  ('GET&D', -11.552323926107896),
#  ('CGPOWER', -11.665793199350428),
#  ('J&KBANK', -11.780155787098343),
#  ('SANGHVIMOV', -11.977751747237484),
#  ('HMT', -12.006034375207237),
#  ('CENTRALBK', -12.025037159818982),
#  ('RELIGARE', -12.152735485564978),
#  ('SREINFRA', -12.313990770298899),
#  ('IOB', -12.569714566921258),
#  ('PATANJALI', -12.624380872509168),
#  ('LUPIN', -12.932015986509242),
#  ('KKCL', -13.00756704439414),
#  ('JAGRAN', -13.069153962390871),
#  ('GLENMARK', -13.129486512334214),
#  ('JISLJALEQS', -13.234145367324052),
#  ('IDEA', -13.29165804077289),
#  ('SUZLON', -14.061194826948341),
#  ('TEXRAIL', -14.092689245330426),
#  ('RPOWER', -14.29888763133532),
#  ('RELINFRA', -16.181657953367544),
#  ('EVEREADY', -17.35801924202515),
#  ('BLUEDART', -18.524567556209167),
#  ('RCOM', -18.973207747142297),
#  ('RELCAPITAL', -19.70123367106686),
#  ('HDIL', -20.725859103446066),
#  ('PUNJLLOYD', -23.000202999904182),
#  ('MERCATOR', -25.222735242106697),
#  ('EMCO', -26.453048795047454),
#  ('MCLEODRUSS', -34.668492669349355)]

# %%
# Drawdown
def drawdown(returns) -> float:
    """Takes a time series of asset returns.
    Computes and returns the drawdown not a list."""
    wealth_index = 1000*(1+returns).cumprod()
    previous_peaks = wealth_index.cummax()
    drawdowns = (wealth_index - previous_peaks)/previous_peaks
    return drawdowns

def get_drawdowns(data, stock):
    returns = get_returns(data, stock)
    return drawdown(returns)

drawdowns = {}

for stock in stocks:
    drawdowns[stock] = get_drawdowns(data, stock)

# %%
min_drawdowns = {}
for stock in stocks:
    min_drawdowns[stock] = drawdowns[stock].min()

# %%
mean_drawdown = np.mean(list(min_drawdowns.values()))
std_drawdown = np.std(list(min_drawdowns.values()))

normalized_drawdowns = {}
for stock in stocks:
    normalized_drawdowns[stock] = (min_drawdowns[stock] - mean_drawdown) / std_drawdown

mean_sharpes_ratio = np.mean(list(sharpes_ratios.values()))
std_sharpes_ratio = np.std(list(sharpes_ratios.values()))

normalized_sharpes_ratios = {}
for stock in stocks:
    normalized_sharpes_ratios[stock] = (sharpes_ratios[stock] - mean_sharpes_ratio) / std_sharpes_ratio

# %%
def get_score(stock, weights):
    return weights[0]*normalized_sharpes_ratios[stock] + weights[1]*normalized_drawdowns[stock]

# %%
import sys
import os
os.getcwd()

SCRIPT_DIR = os.path.dirname(os.path.abspath('../../markowitz/get_returns.py'))
sys.path.append(os.path.dirname(SCRIPT_DIR))
# # import from ../../markowitz folder
# from ...markowitz import get_returns

# %%
from markowitz.get_returns import get_returns_fun
def returns_on_weights(weights = [0.5, 0.5]):
    # select the top 40 stocks based on the score
    scores = {}
    for stock in stocks:
        scores[stock] = get_score(stock, weights)
    sorted_scores = sorted(scores.items(), key=lambda kv: kv[1], reverse=True)
    top_stocks = sorted_scores[:40]
    # stock names
    top_stocks = [stock[0] for stock in top_stocks]
    returns, vol, portfolio = get_returns_fun(top_stocks)
    return returns, vol, portfolio

for w in range(0, 40):
    weights = [w/40, 1 - w/40]
    returns, vol, portfolio = returns_on_weights(weights)
    print('Weights: {}, Returns: {}'.format(weights, returns.mean()*252))
    print('Volatility: {}'.format(vol))
# Out:
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'SANOFI', 'COLPAL', 'PGHH', 'SKFINDIA', 'HCLTECH', 'POWERGRID', 'AIAENG', 'NAUKRI', 'LT', 'GRINDWELL', 'CUB', 'BAJAJHLDNG', 'RELIANCE', 'ATUL', 'MARICO', 'TCS', 'PIDILITIND', 'AARTIIND', 'AKZOINDIA', 'KOTAKBANK', 'DABUR', 'PETRONET', 'HONAUT', 'NTPC', 'BAJAJ-AUTO', 'PGHL', 'SOLARINDS', 'RATNAMANI', 'BAJAJFINSV', 'TATACHEM', 'INFY', 'ITC', 'ASIANPAINT', 'ICICIBANK', 'CONCOR', 'JSWHL', 'TATAINVEST', 'ALKYLAMINE']
# Minimum variance -  2.8688167260276335e-05
# Returns of MVP -  0.05364325118708546
# Next two lines should be same
# 0.03124901197458549
# 0.031249011974585482
# Returns of Tangency portfolio (Bias) -  43.4031034406899 %
# No errors
# Returns of Tangency portfolio -  6.604063799851745 %
# Weights: [0.0, 1.0], Returns: 1664.2240775626396
# Volatility: 0.12932091169327722
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHH', 'SANOFI', 'COLPAL', 'SKFINDIA', 'HCLTECH', 'NAUKRI', 'POWERGRID', 'AIAENG', 'CUB', 'LT', 'GRINDWELL', 'BAJAJHLDNG', 'RELIANCE', 'ATUL', 'MARICO', 'TCS', 'PIDILITIND', 'AARTIIND', 'AKZOINDIA', 'KOTAKBANK', 'HONAUT', 'DABUR', 'PGHL', 'PETRONET', 'BAJAJ-AUTO', 'NTPC', 'BAJAJFINSV', 'SOLARINDS', 'RATNAMANI', 'TATACHEM', 'ASIANPAINT', 'ICICIBANK', 'INFY', 'JSWHL', 'ITC', 'CONCOR', 'TATAINVEST', 'ALKYLAMINE']
# Minimum variance -  2.8688167260276373e-05
# Returns of MVP -  0.05364325118708546
# Next two lines should be same
# 0.031249011974585485
# 0.031249011974585485
# Returns of Tangency portfolio (Bias) -  43.4031034406899 %
# No errors
# Returns of Tangency portfolio -  6.604063799851745 %
# Weights: [0.025, 0.975], Returns: 1664.2240775626396
# Volatility: 0.12932091169327722
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHH', 'SANOFI', 'COLPAL', 'SKFINDIA', 'NAUKRI', 'CUB', 'HCLTECH', 'AIAENG', 'POWERGRID', 'LT', 'GRINDWELL', 'BAJAJHLDNG', 'RELIANCE', 'ATUL', 'PIDILITIND', 'AARTIIND', 'TCS', 'MARICO', 'AKZOINDIA', 'KOTAKBANK', 'PGHL', 'HONAUT', 'PETRONET', 'DABUR', 'BAJAJFINSV', 'BAJAJ-AUTO', 'NTPC', 'RATNAMANI', 'SOLARINDS', 'TATACHEM', 'ASIANPAINT', 'ICICIBANK', 'INFY', 'JSWHL', 'ALKYLAMINE', 'TATAINVEST', 'CONCOR', 'ITC']
# Minimum variance -  2.8688167260276383e-05
# Returns of MVP -  0.05364325118708546
# Next two lines should be same
# 0.03124901197458549
# 0.031249011974585496
# Returns of Tangency portfolio (Bias) -  43.4031034406899 %
# No errors
# Returns of Tangency portfolio -  6.604063799851745 %
# Weights: [0.05, 0.95], Returns: 1664.2240775626396
# Volatility: 0.12932091169327725
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHH', 'SANOFI', 'COLPAL', 'SKFINDIA', 'NAUKRI', 'CUB', 'AIAENG', 'HCLTECH', 'POWERGRID', 'LT', 'RELIANCE', 'BAJAJHLDNG', 'GRINDWELL', 'ATUL', 'PIDILITIND', 'AARTIIND', 'TCS', 'MARICO', 'PGHL', 'HONAUT', 'KOTAKBANK', 'AKZOINDIA', 'BAJAJFINSV', 'PETRONET', 'DABUR', 'RATNAMANI', 'BAJAJ-AUTO', 'SOLARINDS', 'NTPC', 'TATACHEM', 'ASIANPAINT', 'ICICIBANK', 'ALKYLAMINE', 'JSWHL', 'INFY', 'PHOENIXLTD', 'HEIDELBERG', 'TATAINVEST']
# Minimum variance -  2.8533797072773228e-05
# Returns of MVP -  0.05458110934877247
# Next two lines should be same
# 0.030237890307276687
# 0.03023789030727668
# Returns of Tangency portfolio (Bias) -  42.71547468147545 %
# No errors
# Returns of Tangency portfolio -  6.11477496372399 %
# Weights: [0.075, 0.925], Returns: 1540.9232908584454
# Volatility: 0.12934087828770474
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHH', 'SANOFI', 'COLPAL', 'CUB', 'SKFINDIA', 'NAUKRI', 'AIAENG', 'RELIANCE', 'POWERGRID', 'HCLTECH', 'BAJAJHLDNG', 'LT', 'GRINDWELL', 'ATUL', 'PIDILITIND', 'AARTIIND', 'TCS', 'PGHL', 'MARICO', 'HONAUT', 'KOTAKBANK', 'BAJAJFINSV', 'AKZOINDIA', 'PETRONET', 'DABUR', 'RATNAMANI', 'BAJAJ-AUTO', 'SOLARINDS', 'TATACHEM', 'ASIANPAINT', 'NTPC', 'ICICIBANK', 'ALKYLAMINE', 'JSWHL', 'PHOENIXLTD', 'INFY', 'HEIDELBERG', 'TATAINVEST']
# Minimum variance -  2.8533797072773208e-05
# Returns of MVP -  0.05458110934877247
# Next two lines should be same
# 0.030237890307276687
# 0.030237890307276673
# Returns of Tangency portfolio (Bias) -  42.71547468147545 %
# No errors
# Returns of Tangency portfolio -  6.11477496372399 %
# Weights: [0.1, 0.9], Returns: 1540.9232908584454
# Volatility: 0.12934087828770477
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHH', 'SANOFI', 'CUB', 'COLPAL', 'NAUKRI', 'SKFINDIA', 'RELIANCE', 'AIAENG', 'POWERGRID', 'BAJAJHLDNG', 'HCLTECH', 'LT', 'GRINDWELL', 'ATUL', 'AARTIIND', 'PIDILITIND', 'PGHL', 'TCS', 'HONAUT', 'BAJAJFINSV', 'MARICO', 'KOTAKBANK', 'PETRONET', 'AKZOINDIA', 'DABUR', 'RATNAMANI', 'BAJAJ-AUTO', 'ASIANPAINT', 'SOLARINDS', 'ICICIBANK', 'TATACHEM', 'ALKYLAMINE', 'JSWHL', 'NTPC', 'PHOENIXLTD', 'BAJFINANCE', 'HEIDELBERG', 'POLYPLEX']
# Minimum variance -  2.8396341152800688e-05
# Returns of MVP -  0.05238497011013088
# Next two lines should be same
# 0.030424149708057742
# 0.030424149708057752
# Returns of Tangency portfolio (Bias) -  42.71547468147545 %
# No errors
# Returns of Tangency portfolio -  6.900661738522418 %
# Weights: [0.125, 0.875], Returns: 1738.9667581076492
# Volatility: 0.12930373247650126
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHH', 'CUB', 'SANOFI', 'NAUKRI', 'SKFINDIA', 'COLPAL', 'RELIANCE', 'AIAENG', 'BAJAJHLDNG', 'POWERGRID', 'ATUL', 'HCLTECH', 'LT', 'AARTIIND', 'GRINDWELL', 'PIDILITIND', 'PGHL', 'BAJAJFINSV', 'TCS', 'HONAUT', 'KOTAKBANK', 'MARICO', 'PETRONET', 'AKZOINDIA', 'DABUR', 'RATNAMANI', 'ASIANPAINT', 'ICICIBANK', 'ALKYLAMINE', 'TATACHEM', 'BAJFINANCE', 'BAJAJ-AUTO', 'SOLARINDS', 'JSWHL', 'PHOENIXLTD', 'HEIDELBERG', 'POLYPLEX', 'NTPC']
# Minimum variance -  2.839634115280071e-05
# Returns of MVP -  0.05238497011013088
# Next two lines should be same
# 0.030424149708057745
# 0.030424149708057745
# Returns of Tangency portfolio (Bias) -  42.71547468147545 %
# No errors
# Returns of Tangency portfolio -  6.900661738522418 %
# Weights: [0.15, 0.85], Returns: 1738.9667581076492
# Volatility: 0.1293037324765013
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHH', 'CUB', 'SANOFI', 'NAUKRI', 'RELIANCE', 'SKFINDIA', 'COLPAL', 'AIAENG', 'BAJAJHLDNG', 'ATUL', 'AARTIIND', 'PGHL', 'POWERGRID', 'PIDILITIND', 'LT', 'HCLTECH', 'GRINDWELL', 'BAJAJFINSV', 'HONAUT', 'TCS', 'KOTAKBANK', 'MARICO', 'PETRONET', 'AKZOINDIA', 'DABUR', 'RATNAMANI', 'BAJFINANCE', 'ASIANPAINT', 'ALKYLAMINE', 'ICICIBANK', 'TATACHEM', 'SOLARINDS', 'JSWHL', 'BAJAJ-AUTO', 'PHOENIXLTD', 'BATAINDIA', 'IGL', 'COFORGE']
# Minimum variance -  2.885341894827364e-05
# Returns of MVP -  0.05521760822688737
# Next two lines should be same
# 0.031818627462707354
# 0.03181862746270736
# Returns of Tangency portfolio (Bias) -  44.094009006927394 %
# No errors
# Returns of Tangency portfolio -  3.975448036045681 %
# Weights: [0.175, 0.825], Returns: 1001.8129050835116
# Volatility: 0.12969759257410354
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHH', 'CUB', 'NAUKRI', 'RELIANCE', 'SANOFI', 'SKFINDIA', 'COLPAL', 'PGHL', 'AARTIIND', 'BAJAJHLDNG', 'AIAENG', 'ATUL', 'PIDILITIND', 'BAJAJFINSV', 'POWERGRID', 'LT', 'HONAUT', 'GRINDWELL', 'HCLTECH', 'TCS', 'KOTAKBANK', 'MARICO', 'PETRONET', 'AKZOINDIA', 'BAJFINANCE', 'DABUR', 'RATNAMANI', 'ALKYLAMINE', 'ASIANPAINT', 'ICICIBANK', 'BATAINDIA', 'IGL', 'TATACHEM', 'JSWHL', 'PHOENIXLTD', 'COFORGE', 'SOLARINDS', 'POLYPLEX']
# Minimum variance -  2.8777823455948536e-05
# Returns of MVP -  0.05619549577358107
# Next two lines should be same
# 0.030295812794329816
# 0.03029581279432981
# Returns of Tangency portfolio (Bias) -  42.71547468147545 %
# No errors
# Returns of Tangency portfolio -  3.2858755332676015 %
# Weights: [0.2, 0.8], Returns: 828.0406343834355
# Volatility: 0.12908860425909696
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHH', 'CUB', 'RELIANCE', 'NAUKRI', 'SANOFI', 'SKFINDIA', 'PGHL', 'COLPAL', 'AARTIIND', 'BAJAJFINSV', 'ATUL', 'PIDILITIND', 'BAJAJHLDNG', 'AIAENG', 'HONAUT', 'POWERGRID', 'LT', 'GRINDWELL', 'HCLTECH', 'KOTAKBANK', 'TCS', 'PETRONET', 'BAJFINANCE', 'MARICO', 'AKZOINDIA', 'DABUR', 'RATNAMANI', 'ALKYLAMINE', 'ASIANPAINT', 'IGL', 'BATAINDIA', 'ICICIBANK', 'PHOENIXLTD', 'JSWHL', 'TATACHEM', 'COFORGE', 'POLYPLEX', 'HEIDELBERG']
# Minimum variance -  2.8835147825366207e-05
# Returns of MVP -  0.05731076741977148
# Next two lines should be same
# 0.030163233895623632
# 0.030163233895623618
# Returns of Tangency portfolio (Bias) -  42.71547468147545 %
# No errors
# Returns of Tangency portfolio -  5.02751939440762 %
# Weights: [0.225, 0.775], Returns: 1266.9348873907202
# Volatility: 0.12923300802551946
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHH', 'CUB', 'RELIANCE', 'NAUKRI', 'PGHL', 'SANOFI', 'SKFINDIA', 'BAJAJFINSV', 'AARTIIND', 'PIDILITIND', 'COLPAL', 'ATUL', 'BAJAJHLDNG', 'HONAUT', 'AIAENG', 'POWERGRID', 'LT', 'GRINDWELL', 'KOTAKBANK', 'HCLTECH', 'TCS', 'BAJFINANCE', 'PETRONET', 'MARICO', 'IGL', 'DABUR', 'AKZOINDIA', 'ALKYLAMINE', 'BATAINDIA', 'RATNAMANI', 'ASIANPAINT', 'ICICIBANK', 'COFORGE', 'PHOENIXLTD', 'JSWHL', 'POLYPLEX', 'TATACHEM', 'HEIDELBERG']
# Minimum variance -  2.8835147825366196e-05
# Returns of MVP -  0.05731076741977148
# Next two lines should be same
# 0.030163233895623625
# 0.030163233895623625
# Returns of Tangency portfolio (Bias) -  42.71547468147545 %
# No errors
# Returns of Tangency portfolio -  5.027519394407598 %
# Weights: [0.25, 0.75], Returns: 1266.9348873907147
# Volatility: 0.12923300802551943
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHH', 'CUB', 'RELIANCE', 'NAUKRI', 'PGHL', 'BAJAJFINSV', 'SANOFI', 'AARTIIND', 'SKFINDIA', 'PIDILITIND', 'ATUL', 'HONAUT', 'BAJAJHLDNG', 'COLPAL', 'AIAENG', 'KOTAKBANK', 'POWERGRID', 'BAJFINANCE', 'GRINDWELL', 'LT', 'TCS', 'HCLTECH', 'PETRONET', 'IGL', 'MARICO', 'BATAINDIA', 'ALKYLAMINE', 'DABUR', 'RATNAMANI', 'AKZOINDIA', 'ASIANPAINT', 'ICICIBANK', 'COFORGE', 'PHOENIXLTD', 'JSWHL', 'POLYPLEX', 'BERGEPAINT', 'TATACHEM']
# Minimum variance -  2.8831981094426233e-05
# Returns of MVP -  0.05691818463009479
# Next two lines should be same
# 0.029976218222025584
# 0.029976218222025577
# Returns of Tangency portfolio (Bias) -  42.71547468147545 %
# No errors
# Returns of Tangency portfolio -  4.329751424874084 %
# Weights: [0.275, 0.725], Returns: 1091.0973590682693
# Volatility: 0.12963629624238007
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHH', 'CUB', 'RELIANCE', 'PGHL', 'NAUKRI', 'BAJAJFINSV', 'AARTIIND', 'SANOFI', 'SKFINDIA', 'PIDILITIND', 'HONAUT', 'ATUL', 'BAJAJHLDNG', 'COLPAL', 'BAJFINANCE', 'AIAENG', 'KOTAKBANK', 'POWERGRID', 'TCS', 'GRINDWELL', 'LT', 'HCLTECH', 'PETRONET', 'IGL', 'BATAINDIA', 'MARICO', 'ALKYLAMINE', 'ASIANPAINT', 'DABUR', 'RATNAMANI', 'ICICIBANK', 'AKZOINDIA', 'COFORGE', 'PHOENIXLTD', 'POLYPLEX', 'BERGEPAINT', 'JSWHL', 'BRITANNIA']
# Minimum variance -  2.8847411256494625e-05
# Returns of MVP -  0.05653124062663384
# Next two lines should be same
# 0.02925475143342822
# 0.02925475143342821
# Returns of Tangency portfolio (Bias) -  42.031161050248464 %
# No errors
# Returns of Tangency portfolio -  6.179479817182476 %
# Weights: [0.3, 0.7], Returns: 1557.228913929984
# Volatility: 0.12943413485881197
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'CUB', 'PGHH', 'RELIANCE', 'PGHL', 'BAJAJFINSV', 'NAUKRI', 'AARTIIND', 'PIDILITIND', 'HONAUT', 'SKFINDIA', 'SANOFI', 'ATUL', 'BAJFINANCE', 'BAJAJHLDNG', 'COLPAL', 'KOTAKBANK', 'AIAENG', 'POWERGRID', 'TCS', 'IGL', 'GRINDWELL', 'LT', 'BATAINDIA', 'PETRONET', 'HCLTECH', 'ALKYLAMINE', 'MARICO', 'ASIANPAINT', 'ICICIBANK', 'RATNAMANI', 'DABUR', 'COFORGE', 'PHOENIXLTD', 'BERGEPAINT', 'AKZOINDIA', 'POLYPLEX', 'JSWHL', 'BRITANNIA']
# Minimum variance -  2.8847411256494625e-05
# Returns of MVP -  0.05653124062663384
# Next two lines should be same
# 0.029254751433428226
# 0.029254751433428216
# Returns of Tangency portfolio (Bias) -  42.031161050248464 %
# No errors
# Returns of Tangency portfolio -  6.179479817182476 %
# Weights: [0.325, 0.675], Returns: 1557.228913929984
# Volatility: 0.12943413485881194
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'CUB', 'PGHH', 'PGHL', 'RELIANCE', 'BAJAJFINSV', 'NAUKRI', 'AARTIIND', 'BAJFINANCE', 'HONAUT', 'PIDILITIND', 'ATUL', 'SKFINDIA', 'SANOFI', 'BAJAJHLDNG', 'KOTAKBANK', 'COLPAL', 'AIAENG', 'IGL', 'TCS', 'BATAINDIA', 'POWERGRID', 'GRINDWELL', 'PETRONET', 'LT', 'ALKYLAMINE', 'HCLTECH', 'ASIANPAINT', 'MARICO', 'ICICIBANK', 'COFORGE', 'RATNAMANI', 'BERGEPAINT', 'DABUR', 'PHOENIXLTD', 'UNOMINDA', 'POLYPLEX', 'AKZOINDIA', 'JSWHL']
# Minimum variance -  2.8667522210573976e-05
# Returns of MVP -  0.05511200470018629
# Next two lines should be same
# 0.02975382231410025
# 0.02975382231410023
# Returns of Tangency portfolio (Bias) -  42.031161050248464 %
# No errors
# Returns of Tangency portfolio -  7.561172900136248 %
# Weights: [0.35, 0.65], Returns: 1905.4155708343346
# Volatility: 0.12858156020775166
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHL', 'CUB', 'RELIANCE', 'PGHH', 'BAJAJFINSV', 'NAUKRI', 'BAJFINANCE', 'AARTIIND', 'HONAUT', 'PIDILITIND', 'ATUL', 'SKFINDIA', 'SANOFI', 'BAJAJHLDNG', 'KOTAKBANK', 'IGL', 'COLPAL', 'AIAENG', 'BATAINDIA', 'TCS', 'POWERGRID', 'PETRONET', 'GRINDWELL', 'LT', 'ALKYLAMINE', 'HCLTECH', 'ASIANPAINT', 'UNOMINDA', 'COFORGE', 'ICICIBANK', 'BERGEPAINT', 'RATNAMANI', 'MARICO', 'PHOENIXLTD', 'DABUR', 'POLYPLEX', 'MAHSCOOTER', 'GARFIBRES']
# Minimum variance -  2.947911710697773e-05
# Returns of MVP -  0.05657416696425166
# Next two lines should be same
# 0.029432868796085393
# 0.029432868796085386
# Returns of Tangency portfolio (Bias) -  42.031161050248464 %
# No errors
# Returns of Tangency portfolio -  7.868744639680636 %
# Weights: [0.375, 0.625], Returns: 1982.9236491995202
# Volatility: 0.12922523707266406
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHL', 'CUB', 'BAJAJFINSV', 'RELIANCE', 'PGHH', 'BAJFINANCE', 'AARTIIND', 'NAUKRI', 'HONAUT', 'PIDILITIND', 'ATUL', 'SKFINDIA', 'IGL', 'SANOFI', 'BAJAJHLDNG', 'KOTAKBANK', 'BATAINDIA', 'AIAENG', 'COLPAL', 'TCS', 'PETRONET', 'ALKYLAMINE', 'POWERGRID', 'GRINDWELL', 'LT', 'UNOMINDA', 'COFORGE', 'ASIANPAINT', 'BERGEPAINT', 'ICICIBANK', 'HCLTECH', 'PHOENIXLTD', 'RATNAMANI', 'POLYPLEX', 'MAHSCOOTER', 'MARICO', 'GARFIBRES', 'DABUR']
# Minimum variance -  2.9479117106977747e-05
# Returns of MVP -  0.05657416696425166
# Next two lines should be same
# 0.02943286879608538
# 0.02943286879608539
# Returns of Tangency portfolio (Bias) -  42.031161050248464 %
# No errors
# Returns of Tangency portfolio -  7.868744639680614 %
# Weights: [0.4, 0.6], Returns: 1982.9236491995148
# Volatility: 0.12922523707266412
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHL', 'BAJAJFINSV', 'CUB', 'RELIANCE', 'BAJFINANCE', 'PGHH', 'AARTIIND', 'NAUKRI', 'HONAUT', 'PIDILITIND', 'ATUL', 'IGL', 'SKFINDIA', 'KOTAKBANK', 'BATAINDIA', 'SANOFI', 'BAJAJHLDNG', 'AIAENG', 'COLPAL', 'TCS', 'PETRONET', 'UNOMINDA', 'ALKYLAMINE', 'POWERGRID', 'GRINDWELL', 'LT', 'BERGEPAINT', 'COFORGE', 'ASIANPAINT', 'ICICIBANK', 'MAHSCOOTER', 'PHOENIXLTD', 'POLYPLEX', 'RATNAMANI', 'GARFIBRES', 'HCLTECH', 'BRITANNIA', 'DABUR']
# Minimum variance -  2.960731244955027e-05
# Returns of MVP -  0.05730201391473955
# Next two lines should be same
# 0.02954095270487875
# 0.029540952704878755
# Returns of Tangency portfolio (Bias) -  42.031161050248464 %
# No errors
# Returns of Tangency portfolio -  7.4743955820995245 %
# Weights: [0.425, 0.575], Returns: 1883.5476866890801
# Volatility: 0.12895953549047212
# No errors
# Stocks available: ['HDFCBANK', 'PGHL', 'HINDUNILVR', 'BAJAJFINSV', 'CUB', 'BAJFINANCE', 'RELIANCE', 'PGHH', 'AARTIIND', 'HONAUT', 'NAUKRI', 'PIDILITIND', 'IGL', 'ATUL', 'BATAINDIA', 'KOTAKBANK', 'SKFINDIA', 'BAJAJHLDNG', 'SANOFI', 'UNOMINDA', 'AIAENG', 'TCS', 'ALKYLAMINE', 'PETRONET', 'COLPAL', 'BERGEPAINT', 'COFORGE', 'POWERGRID', 'ASIANPAINT', 'GRINDWELL', 'MAHSCOOTER', 'LT', 'ICICIBANK', 'PHOENIXLTD', 'GARFIBRES', 'POLYPLEX', 'RATNAMANI', 'BRITANNIA', 'JSWHL', 'DABUR']
# Minimum variance -  2.91609183985115e-05
# Returns of MVP -  0.05875917287085919
# Next two lines should be same
# 0.029567304109148554
# 0.029567304109148554
# Returns of Tangency portfolio (Bias) -  42.031161050248464 %
# No errors
# Returns of Tangency portfolio -  7.972295518068728 %
# Weights: [0.45, 0.55], Returns: 2009.0184705533195
# Volatility: 0.12866862514941454
# No errors
# Stocks available: ['HDFCBANK', 'PGHL', 'BAJAJFINSV', 'HINDUNILVR', 'BAJFINANCE', 'CUB', 'RELIANCE', 'PGHH', 'AARTIIND', 'HONAUT', 'NAUKRI', 'PIDILITIND', 'IGL', 'ATUL', 'BATAINDIA', 'KOTAKBANK', 'SKFINDIA', 'BAJAJHLDNG', 'SANOFI', 'UNOMINDA', 'ALKYLAMINE', 'TCS', 'PETRONET', 'AIAENG', 'COLPAL', 'BERGEPAINT', 'COFORGE', 'MAHSCOOTER', 'ASIANPAINT', 'POWERGRID', 'ICICIBANK', 'GARFIBRES', 'GRINDWELL', 'PHOENIXLTD', 'POLYPLEX', 'LT', 'RATNAMANI', 'BRITANNIA', 'BIOCON', 'SRF']
# Minimum variance -  3.0218022979036267e-05
# Returns of MVP -  0.06007263174578892
# Next two lines should be same
# 0.029719831299208792
# 0.029719831299208785
# Returns of Tangency portfolio (Bias) -  42.031161050248464 %
# No errors
# Returns of Tangency portfolio -  6.418069637963586 %
# Weights: [0.475, 0.525], Returns: 1617.3535487668237
# Volatility: 0.12844806194665798
# No errors
# Stocks available: ['HDFCBANK', 'PGHL', 'BAJAJFINSV', 'BAJFINANCE', 'HINDUNILVR', 'CUB', 'RELIANCE', 'PGHH', 'AARTIIND', 'HONAUT', 'IGL', 'NAUKRI', 'PIDILITIND', 'BATAINDIA', 'ATUL', 'KOTAKBANK', 'UNOMINDA', 'SKFINDIA', 'BAJAJHLDNG', 'SANOFI', 'ALKYLAMINE', 'PETRONET', 'TCS', 'BERGEPAINT', 'AIAENG', 'COFORGE', 'MAHSCOOTER', 'COLPAL', 'ASIANPAINT', 'GARFIBRES', 'ICICIBANK', 'PHOENIXLTD', 'POLYPLEX', 'BIOCON', 'POWERGRID', 'GRINDWELL', 'TATAMETALI', 'BRITANNIA', 'RATNAMANI', 'LT']
# Minimum variance -  3.0118104178668403e-05
# Returns of MVP -  0.058969725159419006
# Next two lines should be same
# 0.03010991465108085
# 0.030109914651080864
# Returns of Tangency portfolio (Bias) -  42.71547468147545 %
# No errors
# Returns of Tangency portfolio -  6.353051668069121 %
# Weights: [0.5, 0.5], Returns: 1600.9690203534185
# Volatility: 0.12944783012760272
# No errors
# Stocks available: ['HDFCBANK', 'PGHL', 'BAJFINANCE', 'BAJAJFINSV', 'HINDUNILVR', 'RELIANCE', 'CUB', 'PGHH', 'AARTIIND', 'HONAUT', 'IGL', 'PIDILITIND', 'NAUKRI', 'BATAINDIA', 'ATUL', 'UNOMINDA', 'KOTAKBANK', 'BAJAJHLDNG', 'SKFINDIA', 'SANOFI', 'ALKYLAMINE', 'BERGEPAINT', 'PETRONET', 'TCS', 'COFORGE', 'MAHSCOOTER', 'AIAENG', 'GARFIBRES', 'ASIANPAINT', 'TATAMETALI', 'BIOCON', 'COLPAL', 'ICICIBANK', 'POLYPLEX', 'PHOENIXLTD', 'SRF', 'SUNDRMFAST', 'BRITANNIA', 'POWERGRID', 'RATNAMANI']
# Minimum variance -  3.0652713647903695e-05
# Returns of MVP -  0.058830760911376956
# Next two lines should be same
# 0.02745326476326872
# 0.027453264763268724
# Returns of Tangency portfolio (Bias) -  39.99781833846661 %
# No errors
# Returns of Tangency portfolio -  6.895263850543731 %
# Weights: [0.525, 0.475], Returns: 1737.6064903370202
# Volatility: 0.12814708663660723
# No errors
# Stocks available: ['HDFCBANK', 'BAJFINANCE', 'PGHL', 'BAJAJFINSV', 'HINDUNILVR', 'RELIANCE', 'CUB', 'IGL', 'HONAUT', 'AARTIIND', 'PGHH', 'PIDILITIND', 'BATAINDIA', 'NAUKRI', 'UNOMINDA', 'ATUL', 'KOTAKBANK', 'BAJAJHLDNG', 'SKFINDIA', 'ALKYLAMINE', 'SANOFI', 'BERGEPAINT', 'PETRONET', 'MAHSCOOTER', 'COFORGE', 'TCS', 'TATAMETALI', 'GARFIBRES', 'BIOCON', 'AIAENG', 'ASIANPAINT', 'ICICIBANK', 'POLYPLEX', 'PHOENIXLTD', 'SUNDRMFAST', 'SRF', 'COLPAL', 'BRITANNIA', 'COROMANDEL', 'NAVINFLUOR']
# Minimum variance -  3.2981824504454404e-05
# Returns of MVP -  0.06569134623117812
# Next two lines should be same
# 0.02716783179977954
# 0.02716783179977954
# Returns of Tangency portfolio (Bias) -  39.99781833846661 %
# No errors
# Returns of Tangency portfolio -  6.858719788726941 %
# Weights: [0.55, 0.44999999999999996], Returns: 1728.3973867591892
# Volatility: 0.12861704671201082
# No errors
# Stocks available: ['HDFCBANK', 'BAJFINANCE', 'PGHL', 'BAJAJFINSV', 'HINDUNILVR', 'RELIANCE', 'CUB', 'IGL', 'HONAUT', 'AARTIIND', 'PGHH', 'BATAINDIA', 'PIDILITIND', 'NAUKRI', 'UNOMINDA', 'ATUL', 'KOTAKBANK', 'BAJAJHLDNG', 'SKFINDIA', 'ALKYLAMINE', 'BERGEPAINT', 'TATAMETALI', 'MAHSCOOTER', 'SANOFI', 'COFORGE', 'PETRONET', 'BIOCON', 'GARFIBRES', 'TCS', 'ASIANPAINT', 'SUNDRMFAST', 'POLYPLEX', 'AIAENG', 'PHOENIXLTD', 'ICICIBANK', 'SRF', 'OLECTRA', 'COROMANDEL', 'BRITANNIA', 'NAVINFLUOR']
# Minimum variance -  3.402659675951254e-05
# Returns of MVP -  0.06965689926257124
# Next two lines should be same
# 0.027373998511228598
# 0.027373998511228594
# Returns of Tangency portfolio (Bias) -  39.99781833846661 %
# No errors
# Returns of Tangency portfolio -  7.189192492153484 %
# Weights: [0.575, 0.42500000000000004], Returns: 1811.676508022678
# Volatility: 0.12810337238974556
# No errors
# Stocks available: ['HDFCBANK', 'BAJFINANCE', 'PGHL', 'BAJAJFINSV', 'RELIANCE', 'HINDUNILVR', 'CUB', 'IGL', 'HONAUT', 'AARTIIND', 'PGHH', 'BATAINDIA', 'PIDILITIND', 'UNOMINDA', 'NAUKRI', 'ATUL', 'KOTAKBANK', 'TATAMETALI', 'ALKYLAMINE', 'BAJAJHLDNG', 'BERGEPAINT', 'SKFINDIA', 'MAHSCOOTER', 'COFORGE', 'BIOCON', 'PETRONET', 'SANOFI', 'GARFIBRES', 'TCS', 'OLECTRA', 'SUNDRMFAST', 'ASIANPAINT', 'POLYPLEX', 'PHOENIXLTD', 'SRF', 'ICICIBANK', 'COROMANDEL', 'AIAENG', 'BRITANNIA', 'NAVINFLUOR']
# Minimum variance -  3.402659675951259e-05
# Returns of MVP -  0.06965689926257124
# Next two lines should be same
# 0.027373998511228594
# 0.02737399851122859
# Returns of Tangency portfolio (Bias) -  39.99781833846661 %
# No errors
# Returns of Tangency portfolio -  7.189192492153484 %
# Weights: [0.6, 0.4], Returns: 1811.676508022678
# Volatility: 0.1281033723897457
# No errors
# Stocks available: ['BAJFINANCE', 'HDFCBANK', 'PGHL', 'BAJAJFINSV', 'RELIANCE', 'HINDUNILVR', 'CUB', 'IGL', 'HONAUT', 'AARTIIND', 'BATAINDIA', 'PGHH', 'UNOMINDA', 'PIDILITIND', 'NAUKRI', 'ATUL', 'KOTAKBANK', 'TATAMETALI', 'ALKYLAMINE', 'BERGEPAINT', 'BAJAJHLDNG', 'MAHSCOOTER', 'SKFINDIA', 'BIOCON', 'COFORGE', 'OLECTRA', 'GARFIBRES', 'PETRONET', 'SUNDRMFAST', 'SANOFI', 'TCS', 'ASIANPAINT', 'SRF', 'COROMANDEL', 'POLYPLEX', 'PHOENIXLTD', 'ICICIBANK', 'NAVINFLUOR', 'BRITANNIA', 'AIAENG']
# Minimum variance -  3.402659675951257e-05
# Returns of MVP -  0.06965689926257124
# Next two lines should be same
# 0.0273739985112286
# 0.027373998511228594
# Returns of Tangency portfolio (Bias) -  39.99781833846661 %
# No errors
# Returns of Tangency portfolio -  7.189192492153484 %
# Weights: [0.625, 0.375], Returns: 1811.676508022678
# Volatility: 0.12810337238974562
# No errors
# Stocks available: ['BAJFINANCE', 'HDFCBANK', 'PGHL', 'BAJAJFINSV', 'IGL', 'RELIANCE', 'HINDUNILVR', 'CUB', 'HONAUT', 'AARTIIND', 'BATAINDIA', 'UNOMINDA', 'PGHH', 'PIDILITIND', 'NAUKRI', 'ATUL', 'KOTAKBANK', 'TATAMETALI', 'ALKYLAMINE', 'BERGEPAINT', 'OLECTRA', 'MAHSCOOTER', 'BIOCON', 'BAJAJHLDNG', 'COFORGE', 'GARFIBRES', 'SKFINDIA', 'SUNDRMFAST', 'PETRONET', 'COROMANDEL', 'SRF', 'ASIANPAINT', 'SANOFI', 'TCS', 'POLYPLEX', 'PHOENIXLTD', 'ICICIBANK', 'NAVINFLUOR', 'BRITANNIA', 'KEI']
# Minimum variance -  3.4432510431009076e-05
# Returns of MVP -  0.07048209696125518
# Next two lines should be same
# 0.027430798954503188
# 0.02743079895450319
# Returns of Tangency portfolio (Bias) -  39.99781833846661 %
# No errors
# Returns of Tangency portfolio -  6.196454364445936 %
# Weights: [0.65, 0.35], Returns: 1561.506499840376
# Volatility: 0.12797158705028738
# No errors
# Stocks available: ['BAJFINANCE', 'PGHL', 'HDFCBANK', 'BAJAJFINSV', 'IGL', 'RELIANCE', 'CUB', 'HINDUNILVR', 'HONAUT', 'BATAINDIA', 'UNOMINDA', 'AARTIIND', 'PGHH', 'PIDILITIND', 'NAUKRI', 'TATAMETALI', 'ATUL', 'KOTAKBANK', 'OLECTRA', 'BERGEPAINT', 'ALKYLAMINE', 'MAHSCOOTER', 'BIOCON', 'COFORGE', 'BAJAJHLDNG', 'SUNDRMFAST', 'GARFIBRES', 'SKFINDIA', 'COROMANDEL', 'PETRONET', 'SRF', 'ASIANPAINT', 'POLYPLEX', 'PHOENIXLTD', 'TCS', 'BHARATRAS', 'ICICIBANK', 'SANOFI', 'KEI', 'NAVINFLUOR']
# Minimum variance -  3.438918278320704e-05
# Returns of MVP -  0.0699497383477965
# Next two lines should be same
# 0.02726040417122216
# 0.027260404171222156
# Returns of Tangency portfolio (Bias) -  39.99781833846661 %
# No errors
# Returns of Tangency portfolio -  6.326283429761337 %
# Weights: [0.675, 0.32499999999999996], Returns: 1594.2234242998568
# Volatility: 0.12837094817778785
# No errors
# Stocks available: ['BAJFINANCE', 'PGHL', 'BAJAJFINSV', 'HDFCBANK', 'IGL', 'RELIANCE', 'CUB', 'HINDUNILVR', 'UNOMINDA', 'BATAINDIA', 'HONAUT', 'AARTIIND', 'PGHH', 'PIDILITIND', 'TATAMETALI', 'NAUKRI', 'ATUL', 'KOTAKBANK', 'OLECTRA', 'BERGEPAINT', 'BIOCON', 'MAHSCOOTER', 'ALKYLAMINE', 'SUNDRMFAST', 'COFORGE', 'GARFIBRES', 'BAJAJHLDNG', 'COROMANDEL', 'SRF', 'PETRONET', 'BHARATRAS', 'SKFINDIA', 'ASIANPAINT', 'POLYPLEX', 'KEI', 'PHOENIXLTD', 'ICICIBANK', 'TCS', 'NAVINFLUOR', 'SANOFI']
# Minimum variance -  3.438918278320701e-05
# Returns of MVP -  0.0699497383477965
# Next two lines should be same
# 0.027260404171222163
# 0.027260404171222156
# Returns of Tangency portfolio (Bias) -  39.99781833846661 %
# No errors
# Returns of Tangency portfolio -  6.326283429761315 %
# Weights: [0.7, 0.30000000000000004], Returns: 1594.2234242998513
# Volatility: 0.12837094817778785
# No errors
# Stocks available: ['BAJFINANCE', 'PGHL', 'BAJAJFINSV', 'HDFCBANK', 'IGL', 'RELIANCE', 'UNOMINDA', 'CUB', 'BATAINDIA', 'HINDUNILVR', 'HONAUT', 'AARTIIND', 'PIDILITIND', 'PGHH', 'TATAMETALI', 'OLECTRA', 'NAUKRI', 'KOTAKBANK', 'ATUL', 'BIOCON', 'BERGEPAINT', 'MAHSCOOTER', 'ALKYLAMINE', 'SUNDRMFAST', 'COFORGE', 'GARFIBRES', 'BHARATRAS', 'COROMANDEL', 'BAJAJHLDNG', 'SRF', 'KEI', 'PETRONET', 'SKFINDIA', 'POLYPLEX', 'ASIANPAINT', 'PHOENIXLTD', 'NAVINFLUOR', 'ICICIBANK', 'TCS', 'BRITANNIA']
# Minimum variance -  3.6453647240841785e-05
# Returns of MVP -  0.07414485922891956
# Next two lines should be same
# 0.027698108497719517
# 0.02769810849771952
# Returns of Tangency portfolio (Bias) -  40.672348510712084 %
# No errors
# Returns of Tangency portfolio -  6.039059574620409 %
# Weights: [0.725, 0.275], Returns: 1521.843012804343
# Volatility: 0.12917348755644636
# No errors
# Stocks available: ['BAJFINANCE', 'PGHL', 'BAJAJFINSV', 'HDFCBANK', 'IGL', 'RELIANCE', 'UNOMINDA', 'BATAINDIA', 'CUB', 'HONAUT', 'HINDUNILVR', 'AARTIIND', 'TATAMETALI', 'PIDILITIND', 'PGHH', 'OLECTRA', 'NAUKRI', 'KOTAKBANK', 'ATUL', 'BIOCON', 'MAHSCOOTER', 'BERGEPAINT', 'ALKYLAMINE', 'SUNDRMFAST', 'BHARATRAS', 'GARFIBRES', 'COFORGE', 'COROMANDEL', 'KEI', 'SRF', 'BAJAJHLDNG', 'PETRONET', 'POLYPLEX', 'ASIANPAINT', 'SKFINDIA', 'PHOENIXLTD', 'NAVINFLUOR', 'ICICIBANK', 'SUDARSCHEM', 'BALKRISIND']
# Minimum variance -  3.9824790554399894e-05
# Returns of MVP -  0.07686253041545577
# Next two lines should be same
# 0.026852202147240135
# 0.02685220214724012
# Returns of Tangency portfolio (Bias) -  39.99781833846661 %
# No errors
# Returns of Tangency portfolio -  6.952779842474599 %
# Weights: [0.75, 0.25], Returns: 1752.1005203035988
# Volatility: 0.1294853552480663
# No errors
# Stocks available: ['BAJFINANCE', 'PGHL', 'BAJAJFINSV', 'HDFCBANK', 'IGL', 'UNOMINDA', 'RELIANCE', 'BATAINDIA', 'CUB', 'HONAUT', 'HINDUNILVR', 'AARTIIND', 'TATAMETALI', 'OLECTRA', 'PIDILITIND', 'PGHH', 'NAUKRI', 'KOTAKBANK', 'BIOCON', 'ATUL', 'MAHSCOOTER', 'BERGEPAINT', 'BHARATRAS', 'SUNDRMFAST', 'ALKYLAMINE', 'GARFIBRES', 'COFORGE', 'COROMANDEL', 'KEI', 'SRF', 'BAJAJHLDNG', 'PETRONET', 'POLYPLEX', 'SUDARSCHEM', 'ASIANPAINT', 'PHOENIXLTD', 'BALKRISIND', 'NAVINFLUOR', 'PCBL', 'SKFINDIA']
# Minimum variance -  3.925081822177647e-05
# Returns of MVP -  0.07656326218439258
# Next two lines should be same
# 0.026800151832931655
# 0.026800151832931655
# Returns of Tangency portfolio (Bias) -  39.99781833846661 %
# No errors
# Returns of Tangency portfolio -  6.646177160945133 %
# Weights: [0.775, 0.22499999999999998], Returns: 1674.8366445581735
# Volatility: 0.129537839153333
# No errors
# Stocks available: ['BAJFINANCE', 'PGHL', 'BAJAJFINSV', 'HDFCBANK', 'IGL', 'UNOMINDA', 'BATAINDIA', 'RELIANCE', 'CUB', 'HONAUT', 'HINDUNILVR', 'AARTIIND', 'TATAMETALI', 'OLECTRA', 'PIDILITIND', 'PGHH', 'NAUKRI', 'BIOCON', 'BHARATRAS', 'KOTAKBANK', 'ATUL', 'MAHSCOOTER', 'BERGEPAINT', 'SUNDRMFAST', 'ALKYLAMINE', 'COROMANDEL', 'KEI', 'GARFIBRES', 'COFORGE', 'SRF', 'PCBL', 'SUDARSCHEM', 'BALKRISIND', 'BAJAJHLDNG', 'POLYPLEX', 'PETRONET', 'ASIANPAINT', 'NAVINFLUOR', 'PHOENIXLTD', 'ESCORTS']
# Minimum variance -  4.0052340628211295e-05
# Returns of MVP -  0.08164396687866393
# Next two lines should be same
# 0.027661143263752967
# 0.02766114326375296
# Returns of Tangency portfolio (Bias) -  40.672348510712084 %
# No errors
# Returns of Tangency portfolio -  5.528706701092023 %
# Weights: [0.8, 0.19999999999999996], Returns: 1393.23408867519
# Volatility: 0.1292576117630117
# No errors
# Stocks available: ['BAJFINANCE', 'PGHL', 'BAJAJFINSV', 'HDFCBANK', 'IGL', 'UNOMINDA', 'BATAINDIA', 'RELIANCE', 'HONAUT', 'CUB', 'TATAMETALI', 'HINDUNILVR', 'OLECTRA', 'AARTIIND', 'PIDILITIND', 'PGHH', 'BHARATRAS', 'BIOCON', 'NAUKRI', 'KOTAKBANK', 'MAHSCOOTER', 'BERGEPAINT', 'SUNDRMFAST', 'ATUL', 'ALKYLAMINE', 'KEI', 'COROMANDEL', 'GARFIBRES', 'COFORGE', 'PCBL', 'SRF', 'SUDARSCHEM', 'DHANI', 'BALKRISIND', 'ESCORTS', 'HEG', 'POLYPLEX', 'BAJAJHLDNG', 'PETRONET', 'JSWSTEEL']
# Minimum variance -  3.997074929935289e-05
# Returns of MVP -  0.0809222575558044
# Next two lines should be same
# 0.02762433670399915
# 0.02762433670399916
# Returns of Tangency portfolio (Bias) -  40.672348510712084 %
# No errors
# Returns of Tangency portfolio -  5.351955481095683 %
# Weights: [0.825, 0.17500000000000004], Returns: 1348.692781236112
# Volatility: 0.1293491029567867
# No errors
# Stocks available: ['BAJFINANCE', 'PGHL', 'BAJAJFINSV', 'IGL', 'HDFCBANK', 'UNOMINDA', 'BATAINDIA', 'RELIANCE', 'HONAUT', 'TATAMETALI', 'OLECTRA', 'CUB', 'AARTIIND', 'HINDUNILVR', 'PIDILITIND', 'BHARATRAS', 'PGHH', 'BIOCON', 'MAHSCOOTER', 'NAUKRI', 'KOTAKBANK', 'SUNDRMFAST', 'BERGEPAINT', 'ATUL', 'KEI', 'ALKYLAMINE', 'COROMANDEL', 'DHANI', 'GARFIBRES', 'PCBL', 'COFORGE', 'SRF', 'HEG', 'SUDARSCHEM', 'BALKRISIND', 'ESCORTS', 'JSWSTEEL', 'GRAPHITE', 'POLYPLEX', 'NAVINFLUOR']
# Minimum variance -  4.118262489862234e-05
# Returns of MVP -  0.08501844650072865
# Next two lines should be same
# 0.02749511043048481
# 0.027495110430484814
# Returns of Tangency portfolio (Bias) -  40.672348510712084 %
# No errors
# Returns of Tangency portfolio -  4.926801505860956 %
# Weights: [0.85, 0.15000000000000002], Returns: 1241.5539794769609
# Volatility: 0.12967628546000265
# No errors
# Stocks available: ['BAJFINANCE', 'PGHL', 'BAJAJFINSV', 'IGL', 'HDFCBANK', 'UNOMINDA', 'BATAINDIA', 'RELIANCE', 'TATAMETALI', 'OLECTRA', 'HONAUT', 'CUB', 'AARTIIND', 'HINDUNILVR', 'BHARATRAS', 'PIDILITIND', 'BIOCON', 'PGHH', 'MAHSCOOTER', 'SUNDRMFAST', 'DHANI', 'BERGEPAINT', 'KOTAKBANK', 'KEI', 'NAUKRI', 'PCBL', 'ATUL', 'COROMANDEL', 'ALKYLAMINE', 'HEG', 'GARFIBRES', 'COFORGE', 'BALKRISIND', 'SUDARSCHEM', 'SRF', 'ESCORTS', 'GRAPHITE', 'JSWSTEEL', 'POLYPLEX', 'NAVINFLUOR']
# Minimum variance -  4.1182624898622383e-05
# Returns of MVP -  0.08501844650072865
# Next two lines should be same
# 0.027495110430484807
# 0.02749511043048481
# Returns of Tangency portfolio (Bias) -  40.672348510712084 %
# No errors
# Returns of Tangency portfolio -  4.926801505860956 %
# Weights: [0.875, 0.125], Returns: 1241.5539794769609
# Volatility: 0.12967628546000268
# No errors
# Stocks available: ['BAJFINANCE', 'BAJAJFINSV', 'PGHL', 'IGL', 'UNOMINDA', 'HDFCBANK', 'BATAINDIA', 'OLECTRA', 'TATAMETALI', 'RELIANCE', 'HONAUT', 'CUB', 'AARTIIND', 'HINDUNILVR', 'BHARATRAS', 'PIDILITIND', 'DHANI', 'BIOCON', 'PGHH', 'SUNDRMFAST', 'MAHSCOOTER', 'KEI', 'HEG', 'PCBL', 'BERGEPAINT', 'KOTAKBANK', 'NAUKRI', 'COROMANDEL', 'ATUL', 'ALKYLAMINE', 'GARFIBRES', 'BALKRISIND', 'SUDARSCHEM', 'ESCORTS', 'COFORGE', 'GRAPHITE', 'SRF', 'JSWSTEEL', 'HSCL', 'WSTCSTPAPR']
# Minimum variance -  4.0790394971028845e-05
# Returns of MVP -  0.08634863574872309
# Next two lines should be same
# 0.02766563914225348
# 0.02766563914225348
# Returns of Tangency portfolio (Bias) -  40.672348510712084 %
# No errors
# Returns of Tangency portfolio -  5.540177192170126 %
# Weights: [0.9, 0.09999999999999998], Returns: 1396.1246524268718
# Volatility: 0.12939604912553215
# No errors
# Stocks available: ['BAJFINANCE', 'BAJAJFINSV', 'PGHL', 'IGL', 'UNOMINDA', 'HDFCBANK', 'BATAINDIA', 'OLECTRA', 'TATAMETALI', 'RELIANCE', 'HONAUT', 'CUB', 'AARTIIND', 'BHARATRAS', 'HINDUNILVR', 'DHANI', 'PIDILITIND', 'BIOCON', 'HEG', 'PCBL', 'KEI', 'SUNDRMFAST', 'MAHSCOOTER', 'PGHH', 'BERGEPAINT', 'KOTAKBANK', 'COROMANDEL', 'NAUKRI', 'GRAPHITE', 'ALKYLAMINE', 'BALKRISIND', 'ESCORTS', 'ATUL', 'SUDARSCHEM', 'GARFIBRES', 'COFORGE', 'SRF', 'JSWSTEEL', 'HSCL', 'WSTCSTPAPR']
# Minimum variance -  4.0790394971028866e-05
# Returns of MVP -  0.08634863574872309
# Next two lines should be same
# 0.02766563914225349
# 0.02766563914225347
# Returns of Tangency portfolio (Bias) -  40.672348510712084 %
# No errors
# Returns of Tangency portfolio -  5.540177192170126 %
# Weights: [0.925, 0.07499999999999996], Returns: 1396.1246524268718
# Volatility: 0.12939604912553207
# No errors
# Stocks available: ['BAJFINANCE', 'BAJAJFINSV', 'PGHL', 'IGL', 'UNOMINDA', 'HDFCBANK', 'OLECTRA', 'BATAINDIA', 'TATAMETALI', 'RELIANCE', 'HONAUT', 'CUB', 'BHARATRAS', 'DHANI', 'AARTIIND', 'HINDUNILVR', 'HEG', 'BIOCON', 'PIDILITIND', 'PCBL', 'KEI', 'SUNDRMFAST', 'MAHSCOOTER', 'BERGEPAINT', 'PGHH', 'GRAPHITE', 'COROMANDEL', 'KOTAKBANK', 'ESCORTS', 'BALKRISIND', 'SUDARSCHEM', 'ALKYLAMINE', 'NAUKRI', 'GARFIBRES', 'ATUL', 'COFORGE', 'HSCL', 'JSWSTEEL', 'SRF', 'WSTCSTPAPR']
# Minimum variance -  4.079039497102887e-05
# Returns of MVP -  0.08634863574872309
# Next two lines should be same
# 0.027665639142253475
# 0.027665639142253475
# Returns of Tangency portfolio (Bias) -  40.672348510712084 %
# No errors
# Returns of Tangency portfolio -  5.540177192170126 %
# Weights: [0.95, 0.050000000000000044], Returns: 1396.1246524268718
# Volatility: 0.12939604912553218
# No errors
# Stocks available: ['BAJFINANCE', 'BAJAJFINSV', 'PGHL', 'IGL', 'UNOMINDA', 'OLECTRA', 'BATAINDIA', 'TATAMETALI', 'HDFCBANK', 'RELIANCE', 'DHANI', 'HONAUT', 'BHARATRAS', 'CUB', 'AARTIIND', 'HEG', 'HINDUNILVR', 'PCBL', 'BIOCON', 'PIDILITIND', 'KEI', 'SUNDRMFAST', 'GRAPHITE', 'MAHSCOOTER', 'BERGEPAINT', 'ESCORTS', 'COROMANDEL', 'BALKRISIND', 'PGHH', 'SUDARSCHEM', 'KOTAKBANK', 'HSCL', 'ALKYLAMINE', 'GARFIBRES', 'NAUKRI', 'JSWSTEEL', 'ATUL', 'COFORGE', 'SRF', 'WSTCSTPAPR']
# Minimum variance -  4.0790394971028866e-05
# Returns of MVP -  0.08634863574872309
# Next two lines should be same
# 0.027665639142253482
# 0.02766563914225348
# Returns of Tangency portfolio (Bias) -  40.672348510712084 %
# No errors
# Returns of Tangency portfolio -  5.540177192170126 %
# Weights: [0.975, 0.025000000000000022], Returns: 1396.1246524268718
# Volatility: 0.12939604912553213

# %%
returns, vol, Wtan = returns_on_weights([0.4, 0.6])
# Out:
# No errors
# Stocks available: ['HDFCBANK', 'HINDUNILVR', 'PGHL', 'CUB', 'BAJAJFINSV', 'RELIANCE', 'PGHH', 'BAJFINANCE', 'AARTIIND', 'NAUKRI', 'HONAUT', 'PIDILITIND', 'ATUL', 'SKFINDIA', 'IGL', 'SANOFI', 'BAJAJHLDNG', 'KOTAKBANK', 'BATAINDIA', 'AIAENG', 'COLPAL', 'TCS', 'PETRONET', 'ALKYLAMINE', 'POWERGRID', 'GRINDWELL', 'LT', 'UNOMINDA', 'COFORGE', 'ASIANPAINT', 'BERGEPAINT', 'ICICIBANK', 'HCLTECH', 'PHOENIXLTD', 'RATNAMANI', 'POLYPLEX', 'MAHSCOOTER', 'MARICO', 'GARFIBRES', 'DABUR']
# Minimum variance -  2.9479117106977747e-05
# Returns of MVP -  0.05657416696425166
# Next two lines should be same
# 0.02943286879608538
# 0.02943286879608539
# Returns of Tangency portfolio (Bias) -  42.031161050248464 %
# No errors
# Returns of Tangency portfolio -  7.868744639680614 %

# %%
print(vol)
# Out:
# 0.12922523707266412
