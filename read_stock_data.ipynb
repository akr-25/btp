# %%
import pandas as pd

df = pd.read_json('./data/VBL.json')

df['t'] = pd.to_datetime(df['t'], unit = 's')

date1 = pd.to_datetime('14-06-2023')
date2 = pd.to_datetime('16-06-2023')

filtered  = df[df['t'] >= date1]
filtered
# Out:
# C:\Users\esnd1\AppData\Local\Temp\ipykernel_9588\3459034092.py:7: UserWarning: Parsing '14-06-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   date1 = pd.to_datetime('14-06-2023')
# C:\Users\esnd1\AppData\Local\Temp\ipykernel_9588\3459034092.py:8: UserWarning: Parsing '16-06-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   date2 = pd.to_datetime('16-06-2023')
#            c       h       l       o   s          t        v
# 1635  807.50  828.25  801.00  810.00  ok 2023-06-14  1636909
# 1636  827.20  862.00  816.85  819.80  ok 2023-06-15  3020929
# 1637  821.25  838.75  806.00  835.65  ok 2023-06-16  5484855
# 1638  801.35  822.90  796.00  821.25  ok 2023-06-19  2013822
# 1639  813.35  821.55  803.40  804.15  ok 2023-06-20  2465530
# 1640  819.70  824.00  812.35  815.00  ok 2023-06-21  2411903
# 1641  803.55  820.00  800.80  819.70  ok 2023-06-22  1296116
# ...
