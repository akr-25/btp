# %%
import pandas as pd
from datetime import datetime
df = pd.read_json('./data.json')

# %%
def conv_to_datetime(series):
    new_list = series
    for lst in new_list:
        for t_e in lst:
            t_e[0] = pd.to_datetime(t_e[0], unit='ms')
    series = new_list

# %%
conv_to_datetime(df['esg'])
conv_to_datetime(df['esg_industry'])
df
# Out:
#                                                    esg  \
# 0                                                   []
# 1    [[2021-06-01 00:00:00, 14.44], [2021-07-01 00:...
# 2    [[2021-10-01 00:00:00, 36.21], [2021-11-01 00:...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 215  [[2023-01-01 00:00:00, 6.569999999999999], [20...
# 216  [[2021-05-01 00:00:00, 76.19], [2021-06-01 00:...
# 217  [[2021-06-01 00:00:00, 14.030000000000001], [2...
# 218  [[2023-02-01 00:00:00, 20.01], [2023-03-01 00:...
# 219  [[2021-06-01 00:00:00, 67.39], [2021-07-01 00:...
#
#                                           esg_industry  \
# 0                                                   []
# 1    [[2021-06-01 00:00:00, 13.83], [2021-07-01 00:...
# 2    [[2021-10-01 00:00:00, 19.939999999999998], [2...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 215  [[2023-01-01 00:00:00, 6.02], [2023-02-01 00:0...
# 216  [[2021-05-01 00:00:00, 66.85], [2021-06-01 00:...
# 217  [[2021-06-01 00:00:00, 18.69], [2021-07-01 00:...
# 218  [[2023-02-01 00:00:00, 20.68], [2023-03-01 00:...
# 219  [[2021-06-01 00:00:00, 61.029999999999994], [2...
#
#                                            industry  \
# 0                         Mining (except Oil & Gas)
# 1              Containers & Packaging Manufacturing
# 2                       Brokerage & Capital Markets
# 3                       Brokerage & Capital Markets
# 4    Architectural, Engineering, & Related Services
# ..                                              ...
# 215                           IT & Network Services
# 216      Chemicals, Plastics & Rubber Products Mfg.
# 217                          Beverage Manufacturing
# 218                             Software & Internet
# 219               Motor Vehicle Parts Manufacturing
#
#                                                  name      ticker
# 0                                      20-Microns-Ltd   20MICRONS
# 1                                    3M-INDIA-LIMITED     3MINDIA
# 2                              5paisa-Capital-Limited      5PAISA
# 3                        A-K-CAPITAL-SERVICES-LIMITED      530499
# 4    A2Z-MAINTENANCE-and-ENGINEERING-SERVICES-LIMITED    A2ZINFRA
# ..                                                ...         ...
# 215                                 Cartrade-Tech-Ltd    CARTRADE
# 216                                 Castrol-India-Ltd  CASTROLIND
# 217                      CCL-PRODUCTS-(INDIA)-LIMITED         CCL
# 218                               CE-Info-Systems-Ltd    MAPMYIND
# 219                                      CEAT-LIMITED     CEATLTD
#
# [220 rows x 5 columns]

# %%
new_df = df.drop(df[df['esg'].apply(lambda x: len(x) == 0)].index)
# Out:
#                                                    esg  \
# 1    [[2021-06-01 00:00:00, 14.44], [2021-07-01 00:...
# 2    [[2021-10-01 00:00:00, 36.21], [2021-11-01 00:...
# 5    [[2021-06-01 00:00:00, 16.98], [2021-07-01 00:...
# 6    [[2021-06-01 00:00:00, 19.55], [2021-07-01 00:...
# 8    [[2021-07-01 00:00:00, 52.959999999999994], [2...
# ..                                                 ...
# 215  [[2023-01-01 00:00:00, 6.569999999999999], [20...
# 216  [[2021-05-01 00:00:00, 76.19], [2021-06-01 00:...
# 217  [[2021-06-01 00:00:00, 14.030000000000001], [2...
# 218  [[2023-02-01 00:00:00, 20.01], [2023-03-01 00:...
# 219  [[2021-06-01 00:00:00, 67.39], [2021-07-01 00:...
#
#                                           esg_industry  \
# 1    [[2021-06-01 00:00:00, 13.83], [2021-07-01 00:...
# 2    [[2021-10-01 00:00:00, 19.939999999999998], [2...
# 5    [[2021-06-01 00:00:00, 26.05], [2021-07-01 00:...
# 6    [[2021-06-01 00:00:00, 28.24], [2021-07-01 00:...
# 8    [[2021-07-01 00:00:00, 66.0], [2021-08-01 00:0...
# ..                                                 ...
# 215  [[2023-01-01 00:00:00, 6.02], [2023-02-01 00:0...
# 216  [[2021-05-01 00:00:00, 66.85], [2021-06-01 00:...
# 217  [[2021-06-01 00:00:00, 18.69], [2021-07-01 00:...
# 218  [[2023-02-01 00:00:00, 20.68], [2023-03-01 00:...
# 219  [[2021-06-01 00:00:00, 61.029999999999994], [2...
#
#                                        industry                          name  \
# 1          Containers & Packaging Manufacturing              3M-INDIA-LIMITED
# 2                   Brokerage & Capital Markets        5paisa-Capital-Limited
# 5                 Health Care & Pharmaceuticals               Aarti-Drugs-Ltd
# 6    Chemicals, Plastics & Rubber Products Mfg.          AARTI-INDUSTRIES-LTD
# 8                Real Estate Financial Services          Aavas-Financiers-Ltd
# ..                                          ...                           ...
# 215                       IT & Network Services             Cartrade-Tech-Ltd
# 216  Chemicals, Plastics & Rubber Products Mfg.             Castrol-India-Ltd
# 217                      Beverage Manufacturing  CCL-PRODUCTS-(INDIA)-LIMITED
# 218                         Software & Internet           CE-Info-Systems-Ltd
# 219           Motor Vehicle Parts Manufacturing                  CEAT-LIMITED
#
#          ticker
# 1       3MINDIA
# 2        5PAISA
# 5    AARTIDRUGS
# 6      AARTIIND
# 8         AAVAS
# ..          ...
# 215    CARTRADE
# 216  CASTROLIND
# 217         CCL
# 218    MAPMYIND
# 219     CEATLTD
#
# [130 rows x 5 columns]

# %%
new_df = new_df.reset_index()

# %%
def remove_esg_after_2023(df): 
    filtered = df.drop(df[df['esg'].apply(lambda x: x[0][0] > pd.to_datetime('01-01-2023'))].index)
    return filtered

new_df = remove_esg_after_2023(new_df)
new_df = new_df.reset_index()

# %%
diff_array = []

esg = new_df['esg']
esg_ind = new_df['esg_industry']

for i in range(len(new_df['esg'])): 
    s = 0; 
    ind_avg = 0; 

    for j in range(len(esg[i])):
        
        t_esg_com = esg[i][j]
        t_esg_ind = esg_ind[i][j]

        t = t_esg_com[0]

        if(t > pd.to_datetime('01-01-2023')):
            break
        
        ind_avg += t_esg_ind[1]; 
        s += (t_esg_com[1] - t_esg_ind[1]);

    ind_avg /= len(esg[i])
    s /= ind_avg
    s /= len(esg[i])

    diff_array.append(s); 
    
new_df['eco_score'] = diff_array

# %%
new_df = new_df[new_df['eco_score'] > 0]

# %%
new_df.
# Out:
# 472
